# %%
import os
import requests
from bs4 import BeautifulSoup
import json
import re
# utf-8
urls = ["https://amuleto.jp/talents"]
actors = []
for url in urls:
    response = requests.get(url)# html lang="ja",
    content = response.content.decode("utf-8")
    soup = BeautifulSoup(content, "html.parser")
    uls = soup.find("section", id="talents").find_all("ul")[:2]
    for i, ul in enumerate(uls):
        a_s = ul.find_all("a", href=re.compile(r"^https://amuleto.jp/talents/"))
        for a in a_s:
            homepage = a["href"]
            name = a.find("div",{ "class":"info"}).find("p").text.replace("\u3000", " ")
            actors.append({"name": name, "homepage": homepage, "sex":"Male" if i == 1 else "Female"})
actors
# name, homepage, sex
# Out:
# [{'name': '楠 大典',
#   'homepage': 'https://amuleto.jp/talents/kusunokitaiten.html',
#   'sex': 'Female'},
#  {'name': '上田 燿司',
#   'homepage': 'https://amuleto.jp/talents/uedayoji.html',
#   'sex': 'Female'},
#  {'name': '大河元気',
#   'homepage': 'https://amuleto.jp/talents/okawagenki.html',
#   'sex': 'Female'},
#  {'name': '山本和臣',
#   'homepage': 'https://amuleto.jp/talents/yamamotokazutomi.html',
#   'sex': 'Female'},
#  {'name': '藤原 祐規',
#   'homepage': 'https://amuleto.jp/talents/fujiwarayuki.html',
#   'sex': 'Female'},
#  {'name': '大須賀 純',
#   'homepage': 'https://amuleto.jp/talents/osuka-jun.html',
#   'sex': 'Female'},
#  {'name': '蓮 岳大',
#   'homepage': 'https://amuleto.jp/talents/hasutakehiro.html',
#   'sex': 'Female'},
#  {'name': '小島 英樹',
#   'homepage': 'https://amuleto.jp/talents/kojimahideki.html',
#   'sex': 'Female'},
#  {'name': '山口 正秀',
#   'homepage': 'https://amuleto.jp/talents/yamaguchimasahide.html',
#   'sex': 'Female'},
#  {'name': '鈴木コウタ',
#   'homepage': 'https://amuleto.jp/talents/suzukikouta.html',
#   'sex': 'Female'},
#  {'name': '久瀬 秋一',
#   'homepage': 'https://amuleto.jp/talents/kuzeshuichi.html',
#   'sex': 'Female'},
#  {'name': '杉浦 隼永',
#   'homepage': 'https://amuleto.jp/talents/sugiurahayato.html',
#   'sex': 'Female'},
#  {'name': '高瀬 泰幸',
#   'homepage': 'https://amuleto.jp/talents/takaseyasuyuki.html',
#   'sex': 'Female'},
#  {'name': '高仲祐之',
#   'homepage': 'https://amuleto.jp/talents/takanakahiroyuki.html',
#   'sex': 'Female'},
#  {'name': '高野 光平',
#   'homepage': 'https://amuleto.jp/talents/takano_kouhei.html',
#   'sex': 'Female'},
#  {'name': '田代 哲哉',
#   'homepage': 'https://amuleto.jp/talents/tashirotetsuya.html',
#   'sex': 'Female'},
#  {'name': '田渕 将平',
#   'homepage': 'https://amuleto.jp/talents/tabuchishohei.html',
#   'sex': 'Female'},
#  {'name': '横田 紘一',
#   'homepage': 'https://amuleto.jp/talents/yokotakoichi.html',
#   'sex': 'Female'},
#  {'name': '米山 伸伍',
#   'homepage': 'https://amuleto.jp/talents/yoneyamashingo.html',
#   'sex': 'Female'},
#  {'name': '一瀬 巧',
#   'homepage': 'https://amuleto.jp/talents/ichinose-takumi.html',
#   'sex': 'Female'},
#  {'name': '滝澤 諒',
#   'homepage': 'https://amuleto.jp/talents/takizawaryo.html',
#   'sex': 'Female'},
#  {'name': '田村ゆかり',
#   'homepage': 'https://amuleto.jp/talents/tamura_yukari.html',
#   'sex': 'Male'},
#  {'name': '永島 由子',
#   'homepage': 'https://amuleto.jp/talents/nagashimayuko.html',
#   'sex': 'Male'},
#  {'name': '明坂 聡美',
#   'homepage': 'https://amuleto.jp/talents/akesakasatomi.html',
#   'sex': 'Male'},
#  {'name': '本多 真梨子',
#   'homepage': 'https://amuleto.jp/talents/honda-mariko.html',
#   'sex': 'Male'},
#  {'name': '木野 日菜',
#   'homepage': 'https://amuleto.jp/talents/kinohina.html',
#   'sex': 'Male'},
#  {'name': '佐久間 紅美',
#   'homepage': 'https://amuleto.jp/talents/sakumakumi.html',
#   'sex': 'Male'},
#  {'name': '真田 アサミ',
#   'homepage': 'https://amuleto.jp/talents/sanadaasami.html',
#   'sex': 'Male'},
#  {'name': '吉田 仁美',
#   'homepage': 'https://amuleto.jp/talents/yoshidahitomi.html',
#   'sex': 'Male'},
#  {'name': '庄子 裕衣',
#   'homepage': 'https://amuleto.jp/talents/shojiyui.html',
#   'sex': 'Male'},
#  {'name': '津川 祝子',
#   'homepage': 'https://amuleto.jp/talents/tsugawashukuko.html',
#   'sex': 'Male'},
#  {'name': '青戸 浩香',
#   'homepage': 'https://amuleto.jp/talents/aotohiroka.html',
#   'sex': 'Male'},
#  {'name': '赤木 春菜',
#   'homepage': 'https://amuleto.jp/talents/akagiharuna.html',
#   'sex': 'Male'},
#  {'name': '安藤 鈴菜',
#   'homepage': 'https://amuleto.jp/talents/andohreina.html',
#   'sex': 'Male'},
#  {'name': '大石 歩佳',
#   'homepage': 'https://amuleto.jp/talents/oishiayuka.html',
#   'sex': 'Male'},
#  {'name': '大森 舞',
#   'homepage': 'https://amuleto.jp/talents/oomorimai.html',
#   'sex': 'Male'},
#  {'name': '岡木 陽夏',
#   'homepage': 'https://amuleto.jp/talents/okakiharuka.html',
#   'sex': 'Male'},
#  {'name': '岡田 千優季',
#   'homepage': 'https://amuleto.jp/talents/okadachiyuki.html',
#   'sex': 'Male'},
#  {'name': '岡本 美歌',
#   'homepage': 'https://amuleto.jp/talents/okamotomika.html',
#   'sex': 'Male'},
#  {'name': '音羽 里奏',
#   'homepage': 'https://amuleto.jp/talents/otowarina.html',
#   'sex': 'Male'},
#  {'name': '今野 優月',
#   'homepage': 'https://amuleto.jp/talents/konnoyuzuki.html',
#   'sex': 'Male'},
#  {'name': '佐藤 舞',
#   'homepage': 'https://amuleto.jp/talents/satoumaii.html',
#   'sex': 'Male'},
#  {'name': '平流 エレン',
#   'homepage': 'https://amuleto.jp/talents/tairaellen.html',
#   'sex': 'Male'},
#  {'name': '武石 あゆ実',
#   'homepage': 'https://amuleto.jp/talents/takeishiayumi.html',
#   'sex': 'Male'},
#  {'name': '田畑 寧々',
#   'homepage': 'https://amuleto.jp/talents/tabatanene.html',
#   'sex': 'Male'},
#  {'name': '中島 優衣',
#   'homepage': 'https://amuleto.jp/talents/nakajimayui.html',
#   'sex': 'Male'},
#  {'name': '中臣 真菜',
#   'homepage': 'https://amuleto.jp/talents/nakatomimana.html',
#   'sex': 'Male'},
#  {'name': '永木 さくら',
#   'homepage': 'https://amuleto.jp/talents/nagakisakura.html',
#   'sex': 'Male'},
#  {'name': '七海 とろろ',
#   'homepage': 'https://amuleto.jp/talents/nanamitororo.html',
#   'sex': 'Male'},
#  {'name': '花原 あんり',
#   'homepage': 'https://amuleto.jp/talents/hanaharaanri.html',
#   'sex': 'Male'},
#  {'name': '宮園 美海',
#   'homepage': 'https://amuleto.jp/talents/miyazonomiumi.html',
#   'sex': 'Male'},
#  {'name': '柳木 みり',
#   'homepage': 'https://amuleto.jp/talents/yanagimiri.html',
#   'sex': 'Male'},
#  {'name': '山本 亜衣',
#   'homepage': 'https://amuleto.jp/talents/yamamotoai.html',
#   'sex': 'Male'},
#  {'name': '山本 彩乃',
#   'homepage': 'https://amuleto.jp/talents/yamamotoayano.html',
#   'sex': 'Male'},
#  {'name': '吉住 絵里加',
#   'homepage': 'https://amuleto.jp/talents/yoshizumierika.html',
#   'sex': 'Male'},
#  {'name': '渡辺 千絢',
#   'homepage': 'https://amuleto.jp/talents/watanabechihiro.html',
#   'sex': 'Male'}]

# %%
len(actors)
# Out:
# 56

# %%
import re
import json
def get_voices(homepage:str):
    response = requests.get(homepage)
    content = response.content
    soup = BeautifulSoup(content, "html.parser")
    voices = []
    #print(soup.find_all("source"))
    #descriptions = 
    script = [i for i in soup.find_all("script") if ".mp3" in str(i)][0]
    # wav or mp3
    files = re.findall(r"https://amuleto.jp/renewal/wp/uploads/.*\.(mp3|wav)", str(script))
    players = soup.find_all("div", {"class":"jp-jplayer"})
    for i, player in enumerate(players):
        description = player.parent.previous_sibling.previous_sibling.text.strip()
        url = files[i]
        name = url.split("/")[-1]
        voices.append({"url": url, "name": name, "description": description})
    
# url, name, description
    return voices
#get_voices("https://amuleto.jp/talents/akesakasatomi.html")
import tqdm
pbar = tqdm.tqdm(actors)
for actor in pbar:
    try:
        actor["voices"] = get_voices(actor["homepage"])
    except:
        actor["voices"] = []
    pbar.set_description(str(len(actor["voices"])))
actors
# Out:
# 1: 100%|██████████| 56/56 [00:39<00:00,  1.43it/s]
# [{'name': '楠 大典',
#   'homepage': 'https://amuleto.jp/talents/kusunokitaiten.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/edef7db207267a4e608a45a3e4489c48.mp3',
#     'name': 'edef7db207267a4e608a45a3e4489c48.mp3',
#     'description': 'ナレーション'}]},
#  {'name': '上田 燿司',
#   'homepage': 'https://amuleto.jp/talents/uedayoji.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/上田燿司_関西弁.mp3',
#     'name': '上田燿司_関西弁.mp3',
#     'description': '台詞1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/上田燿司_ベイリッシュ.mp3',
#     'name': '上田燿司_ベイリッシュ.mp3',
#     'description': '台詞2'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/上田燿司_老け.mp3',
#     'name': '上田燿司_老け.mp3',
#     'description': '台詞3'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/上田燿司_ジョジョ.mp3',
#     'name': '上田燿司_ジョジョ.mp3',
#     'description': '台詞4'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/上田燿司_ドバイ再編集.mp3',
#     'name': '上田燿司_ドバイ再編集.mp3',
#     'description': 'ナレーション'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/上田燿司_ボイスサンプルセリフ2022ver.mp3',
#     'name': '上田燿司_ボイスサンプルセリフ2022ver.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '大河元気',
#   'homepage': 'https://amuleto.jp/talents/okawagenki.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/大河元気ボイス1.mp3',
#     'name': '大河元気ボイス1.mp3',
#     'description': '台詞１'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/大河元気ボイス2.mp3',
#     'name': '大河元気ボイス2.mp3',
#     'description': '台詞2'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/大河元気ボイス3.mp3',
#     'name': '大河元気ボイス3.mp3',
#     'description': '台詞3'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/大河元気ボイス4.mp3',
#     'name': '大河元気ボイス4.mp3',
#     'description': '台詞4'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/大河元気ナレーションHP.mp3',
#     'name': '大河元気ナレーションHP.mp3',
#     'description': 'ナレーション'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/大河元気ボイスサンプル2024フル.mp3',
#     'name': '大河元気ボイスサンプル2024フル.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '山本和臣',
#   'homepage': 'https://amuleto.jp/talents/yamamotokazutomi.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/山本和臣_台詞1.wav',
#     'name': '山本和臣_台詞1.wav',
#     'description': '台詞1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/山本和臣_台詞2.wav',
#     'name': '山本和臣_台詞2.wav',
#     'description': '台詞2'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/山本和臣_台詞3.wav',
#     'name': '山本和臣_台詞3.wav',
#     'description': '台詞3'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/山本和臣_台詞4.wav',
#     'name': '山本和臣_台詞4.wav',
#     'description': '台詞4'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/山本和臣_ナレーション1.wav',
#     'name': '山本和臣_ナレーション1.wav',
#     'description': 'ナレーション1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/山本和臣_ナレーション2.wav',
#     'name': '山本和臣_ナレーション2.wav',
#     'description': 'ナレーション2'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/山本和臣_フルボイス.mp3',
#     'name': '山本和臣_フルボイス.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '藤原 祐規',
#   'homepage': 'https://amuleto.jp/talents/fujiwarayuki.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/藤原祐規１.mp3',
#     'name': '藤原祐規１.mp3',
#     'description': 'フルボイス1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/藤原祐規２.mp3',
#     'name': '藤原祐規２.mp3',
#     'description': 'フルボイス2'}]},
#  {'name': '大須賀 純',
#   'homepage': 'https://amuleto.jp/talents/osuka-jun.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/a5265ba74342c2f52bfcd9e65641afe6.mp3',
#     'name': 'a5265ba74342c2f52bfcd9e65641afe6.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '蓮 岳大',
#   'homepage': 'https://amuleto.jp/talents/hasutakehiro.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/hasu_takehiro_n.mp3',
#     'name': 'hasu_takehiro_n.mp3',
#     'description': 'ナレーション'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/hasu_takehiro_s.mp3',
#     'name': 'hasu_takehiro_s.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '小島 英樹',
#   'homepage': 'https://amuleto.jp/talents/kojimahideki.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/小島英樹_台詞.mp3',
#     'name': '小島英樹_台詞.mp3',
#     'description': 'フルボイス'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/小島英樹_ナレ.mp3',
#     'name': '小島英樹_ナレ.mp3',
#     'description': 'ナレーション'}]},
#  {'name': '山口 正秀',
#   'homepage': 'https://amuleto.jp/talents/yamaguchimasahide.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/山口正秀.mp3',
#     'name': '山口正秀.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '鈴木コウタ',
#   'homepage': 'https://amuleto.jp/talents/suzukikouta.html',
#   'sex': 'Female',
#   'voices': []},
#  {'name': '久瀬 秋一',
#   'homepage': 'https://amuleto.jp/talents/kuzeshuichi.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/久瀬秋一_クレジット_地声.wav',
#     'name': '久瀬秋一_クレジット_地声.wav',
#     'description': '台詞①'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/久瀬秋一_30代くらい_刑事風.mp3',
#     'name': '久瀬秋一_30代くらい_刑事風.mp3',
#     'description': '台詞②'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/久瀬秋一_20代_生意気.mp3',
#     'name': '久瀬秋一_20代_生意気.mp3',
#     'description': '台詞③'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/久瀬秋一_30代くらい_モノ有り.mp3',
#     'name': '久瀬秋一_30代くらい_モノ有り.mp3',
#     'description': '台詞④'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/久瀬秋一_20代前半_ねっとり系.mp3',
#     'name': '久瀬秋一_20代前半_ねっとり系.mp3',
#     'description': '台詞⑤'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/久瀬秋一_30代半ば_武将風.mp3',
#     'name': '久瀬秋一_30代半ば_武将風.mp3',
#     'description': '台詞⑥'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/久瀬秋一_ナレーション_世界遺産風_静かめ-2.mp3',
#     'name': '久瀬秋一_ナレーション_世界遺産風_静かめ-2.mp3',
#     'description': 'ナレーション①'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/久瀬秋一_ナレーション_スポーツ系-2.mp3',
#     'name': '久瀬秋一_ナレーション_スポーツ系-2.mp3',
#     'description': 'ナレーション②'}]},
#  {'name': '杉浦 隼永',
#   'homepage': 'https://amuleto.jp/talents/sugiurahayato.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/191218_sugiura_VoiceSample.mp3',
#     'name': '191218_sugiura_VoiceSample.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '高瀬 泰幸',
#   'homepage': 'https://amuleto.jp/talents/takaseyasuyuki.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/高瀬泰幸_セリフ.mp3',
#     'name': '高瀬泰幸_セリフ.mp3',
#     'description': 'フルボイス'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/高瀬泰幸_ナレ.mp3',
#     'name': '高瀬泰幸_ナレ.mp3',
#     'description': 'ナレーション'}]},
#  {'name': '高仲祐之',
#   'homepage': 'https://amuleto.jp/talents/takanakahiroyuki.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/Takanaka_VoiceSample-1.mp3',
#     'name': 'Takanaka_VoiceSample-1.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '高野 光平',
#   'homepage': 'https://amuleto.jp/talents/takano_kouhei.html',
#   'sex': 'Female',
#   'voices': []},
#  {'name': '田代 哲哉',
#   'homepage': 'https://amuleto.jp/talents/tashirotetsuya.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/田代哲哉ナレーション.mp3',
#     'name': '田代哲哉ナレーション.mp3',
#     'description': 'ナレーション'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/田代哲哉_台詞.mp3',
#     'name': '田代哲哉_台詞.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '田渕 将平',
#   'homepage': 'https://amuleto.jp/talents/tabuchishohei.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/田淵翔平_full_外部用（事務所名なし）-online-audio-converter.com_.mp3',
#     'name': '田淵翔平_full_外部用（事務所名なし）-online-audio-converter.com_.mp3',
#     'description': 'フルボイス'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/田淵翔平_外画風_30代軍人系.wav',
#     'name': '田淵翔平_外画風_30代軍人系.wav',
#     'description': '台詞1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/田淵翔平_外画風_30～40代医師.wav',
#     'name': '田淵翔平_外画風_30～40代医師.wav',
#     'description': '台詞2'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/田淵翔平_アニメ風_筋肉系_叫びあり.wav',
#     'name': '田淵翔平_アニメ風_筋肉系_叫びあり.wav',
#     'description': '台詞3'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/田淵翔平_アニメ風_不良系.wav',
#     'name': '田淵翔平_アニメ風_不良系.wav',
#     'description': '台詞4'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/田淵翔平_外画風_30～40代警察官.wav',
#     'name': '田淵翔平_外画風_30～40代警察官.wav',
#     'description': '台詞5'}]},
#  {'name': '横田 紘一',
#   'homepage': 'https://amuleto.jp/talents/yokotakoichi.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/横田紘一ナレーションサンプル.mp3',
#     'name': '横田紘一ナレーションサンプル.mp3',
#     'description': 'ナレーション'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/横田紘一ボイスサンプル.mp3',
#     'name': '横田紘一ボイスサンプル.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '米山 伸伍',
#   'homepage': 'https://amuleto.jp/talents/yoneyamashingo.html',
#   'sex': 'Female',
#   'voices': []},
#  {'name': '一瀬 巧',
#   'homepage': 'https://amuleto.jp/talents/ichinose-takumi.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/一瀬巧＿ボイスサンプル①-1.mp3',
#     'name': '一瀬巧＿ボイスサンプル①-1.mp3',
#     'description': '台詞1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/一瀬巧_②.wav',
#     'name': '一瀬巧_②.wav',
#     'description': '台詞2'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/一瀬巧_③.wav',
#     'name': '一瀬巧_③.wav',
#     'description': '台詞3'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/一瀬巧_④.wav',
#     'name': '一瀬巧_④.wav',
#     'description': '台詞4'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/一瀬巧_⑤.wav',
#     'name': '一瀬巧_⑤.wav',
#     'description': '台詞5'}]},
#  {'name': '滝澤 諒',
#   'homepage': 'https://amuleto.jp/talents/takizawaryo.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/滝澤諒.mp3',
#     'name': '滝澤諒.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '田村ゆかり',
#   'homepage': 'https://amuleto.jp/talents/tamura_yukari.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/【田村ゆかり】ボイスサンプル-1.mp3',
#     'name': '【田村ゆかり】ボイスサンプル-1.mp3',
#     'description': 'フルボイス'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/【田村ゆかり】ナレーションサンプル-1.mp3',
#     'name': '【田村ゆかり】ナレーションサンプル-1.mp3',
#     'description': 'ナレーション'}]},
#  {'name': '永島 由子',
#   'homepage': 'https://amuleto.jp/talents/nagashimayuko.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/永島由子_ナレーション_katari.mp3',
#     'name': '永島由子_ナレーション_katari.mp3',
#     'description': 'ナレーション1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/永島由子_01ショート.mp3',
#     'name': '永島由子_01ショート.mp3',
#     'description': 'フルボイス1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/永島由子_02ボイス.mp3',
#     'name': '永島由子_02ボイス.mp3',
#     'description': 'フルボイス2'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/永島由子_ナレーション番組系.mp3',
#     'name': '永島由子_ナレーション番組系.mp3',
#     'description': 'ナレーション2'}]},
#  {'name': '明坂 聡美',
#   'homepage': 'https://amuleto.jp/talents/akesakasatomi.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/akesaka_satomi_n.mp3',
#     'name': 'akesaka_satomi_n.mp3',
#     'description': 'ナレーション'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/akesaka_satomi_s.mp3',
#     'name': 'akesaka_satomi_s.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '本多 真梨子',
#   'homepage': 'https://amuleto.jp/talents/honda-mariko.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/本多真梨子_アニメ.mp3',
#     'name': '本多真梨子_アニメ.mp3',
#     'description': 'フルボイス1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/本多真梨子_外画_変更21.mp3',
#     'name': '本多真梨子_外画_変更21.mp3',
#     'description': 'フルボイス2'}]},
#  {'name': '木野 日菜',
#   'homepage': 'https://amuleto.jp/talents/kinohina.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/木野日菜_台詞1.mp3',
#     'name': '木野日菜_台詞1.mp3',
#     'description': 'フルボイス1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/木野日菜_台詞2.mp3',
#     'name': '木野日菜_台詞2.mp3',
#     'description': 'フルボイス2'}]},
#  {'name': '佐久間 紅美',
#   'homepage': 'https://amuleto.jp/talents/sakumakumi.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/佐久間紅美_台詞-1.mp3',
#     'name': '佐久間紅美_台詞-1.mp3',
#     'description': 'フルボイス'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/佐久間紅美_ナレ.mp3',
#     'name': '佐久間紅美_ナレ.mp3',
#     'description': 'ナレーション'}]},
#  {'name': '真田 アサミ',
#   'homepage': 'https://amuleto.jp/talents/sanadaasami.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/真田アサミアニメ系サンプル.mp3',
#     'name': '真田アサミアニメ系サンプル.mp3',
#     'description': 'フルボイス'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/真田アサミ外画サンプル.mp3',
#     'name': '真田アサミ外画サンプル.mp3',
#     'description': '台詞'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/真田アサミナレーションサンプル.mp3',
#     'name': '真田アサミナレーションサンプル.mp3',
#     'description': 'ナレーション'}]},
#  {'name': '吉田 仁美',
#   'homepage': 'https://amuleto.jp/talents/yoshidahitomi.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/吉田仁美_credit_20代後半女性.wav',
#     'name': '吉田仁美_credit_20代後半女性.wav',
#     'description': '台詞1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/吉田仁美_6歳くらい_男の子.wav',
#     'name': '吉田仁美_6歳くらい_男の子.wav',
#     'description': '台詞2'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/吉田仁美_14歳くらい_女の子.wav',
#     'name': '吉田仁美_14歳くらい_女の子.wav',
#     'description': '台詞3'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/吉田仁美_30代_母親.wav',
#     'name': '吉田仁美_30代_母親.wav',
#     'description': '台詞4'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/吉田仁美_30代くらい_懇願泣き有り.wav',
#     'name': '吉田仁美_30代くらい_懇願泣き有り.wav',
#     'description': '台詞5'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/吉田仁美_ナレーション2022.mp3',
#     'name': '吉田仁美_ナレーション2022.mp3',
#     'description': 'ナレーション'}]},
#  {'name': '庄子 裕衣',
#   'homepage': 'https://amuleto.jp/talents/shojiyui.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/syouji.n.mp3',
#     'name': 'syouji.n.mp3',
#     'description': 'ナレーション'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/syouji.s.mp3',
#     'name': 'syouji.s.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '津川 祝子',
#   'homepage': 'https://amuleto.jp/talents/tsugawashukuko.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/cd24687e6bf5ff44550b4fb9ffe6c0a6.mp3',
#     'name': 'cd24687e6bf5ff44550b4fb9ffe6c0a6.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '青戸 浩香',
#   'homepage': 'https://amuleto.jp/talents/aotohiroka.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/青戸浩香-1.mp3',
#     'name': '青戸浩香-1.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '赤木 春菜',
#   'homepage': 'https://amuleto.jp/talents/akagiharuna.html',
#   'sex': 'Male',
#   'voices': []},
#  {'name': '安藤 鈴菜',
#   'homepage': 'https://amuleto.jp/talents/andohreina.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/安藤-玲奈_ボイスサンプル.mp3',
#     'name': '安藤-玲奈_ボイスサンプル.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '大石 歩佳',
#   'homepage': 'https://amuleto.jp/talents/oishiayuka.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/大石歩佳1023.mp3',
#     'name': '大石歩佳1023.mp3',
#     'description': 'フルボイス1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/大石歩佳.mp3',
#     'name': '大石歩佳.mp3',
#     'description': 'フルボイス2'}]},
#  {'name': '大森 舞',
#   'homepage': 'https://amuleto.jp/talents/oomorimai.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/大森舞ボイスサンプル.mp3',
#     'name': '大森舞ボイスサンプル.mp3',
#     'description': 'フルボイス'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/大森舞ナレーションサンプル.mp3',
#     'name': '大森舞ナレーションサンプル.mp3',
#     'description': 'ナレーション'}]},
#  {'name': '岡木 陽夏',
#   'homepage': 'https://amuleto.jp/talents/okakiharuka.html',
#   'sex': 'Male',
#   'voices': []},
#  {'name': '岡田 千優季',
#   'homepage': 'https://amuleto.jp/talents/okadachiyuki.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/d94d24caf443d4ba6769b91e9ef416f6.mp3',
#     'name': 'd94d24caf443d4ba6769b91e9ef416f6.mp3',
#     'description': 'フルボイス'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/3e8b9738824cf04c750d66111e77c9f7.mp3',
#     'name': '3e8b9738824cf04c750d66111e77c9f7.mp3',
#     'description': 'ナレーション'}]},
#  {'name': '岡本 美歌',
#   'homepage': 'https://amuleto.jp/talents/okamotomika.html',
#   'sex': 'Male',
#   'voices': []},
#  {'name': '音羽 里奏',
#   'homepage': 'https://amuleto.jp/talents/otowarina.html',
#   'sex': 'Male',
#   'voices': []},
#  {'name': '今野 優月',
#   'homepage': 'https://amuleto.jp/talents/konnoyuzuki.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/《mp3ファイル》konno_VoiceSample_all-online-audio-converter.com_.mp3',
#     'name': '《mp3ファイル》konno_VoiceSample_all-online-audio-converter.com_.mp3',
#     'description': 'フルボイス'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/konno_VoiceSample_1.wav',
#     'name': 'konno_VoiceSample_1.wav',
#     'description': '台詞1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/konno_VoiceSample_2.wav',
#     'name': 'konno_VoiceSample_2.wav',
#     'description': '台詞2'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/konno_VoiceSample_3.wav',
#     'name': 'konno_VoiceSample_3.wav',
#     'description': '台詞3'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/konno_VoiceSample_4.wav',
#     'name': 'konno_VoiceSample_4.wav',
#     'description': '台詞4'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/konno_VoiceSample_5.wav',
#     'name': 'konno_VoiceSample_5.wav',
#     'description': '台詞5'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/konno_VoiceSample_6.wav',
#     'name': 'konno_VoiceSample_6.wav',
#     'description': '台詞6'}]},
#  {'name': '佐藤 舞',
#   'homepage': 'https://amuleto.jp/talents/satoumaii.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/佐藤舞ボイス1.mp3',
#     'name': '佐藤舞ボイス1.mp3',
#     'description': '台詞1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/佐藤舞2024ボイス2.mp3',
#     'name': '佐藤舞2024ボイス2.mp3',
#     'description': '台詞2'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/佐藤舞2024ボイス３.mp3',
#     'name': '佐藤舞2024ボイス３.mp3',
#     'description': '台詞3'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/佐藤舞ボイス2024ボイス4.mp3',
#     'name': '佐藤舞ボイス2024ボイス4.mp3',
#     'description': '台詞４'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/佐藤舞ボイスサンプル2024_クレジットあり.mp3',
#     'name': '佐藤舞ボイスサンプル2024_クレジットあり.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '平流 エレン',
#   'homepage': 'https://amuleto.jp/talents/tairaellen.html',
#   'sex': 'Male',
#   'voices': []},
#  {'name': '武石 あゆ実',
#   'homepage': 'https://amuleto.jp/talents/takeishiayumi.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/takeishi.n.mp3',
#     'name': 'takeishi.n.mp3',
#     'description': 'ナレーション'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/takeishi.s.mp3',
#     'name': 'takeishi.s.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '田畑 寧々',
#   'homepage': 'https://amuleto.jp/talents/tabatanene.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/田畑＿ボイスサンプル\u3000フル尺.mp3',
#     'name': '田畑＿ボイスサンプル\u3000フル尺.mp3',
#     'description': 'フルボイス'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/田畑_ボイスサンプル①.mp3',
#     'name': '田畑_ボイスサンプル①.mp3',
#     'description': '台詞1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/田畑_ボイスサンプル②.mp3',
#     'name': '田畑_ボイスサンプル②.mp3',
#     'description': '台詞2'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/田畑_ボイスサンプル③.mp3',
#     'name': '田畑_ボイスサンプル③.mp3',
#     'description': '台詞3'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/田畑_ボイスサンプル④.mp3',
#     'name': '田畑_ボイスサンプル④.mp3',
#     'description': '台詞4'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/田畑_ボイスサンプル⑤.mp3',
#     'name': '田畑_ボイスサンプル⑤.mp3',
#     'description': '台詞5'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/田畑_ボイスサンプル⑥.mp3',
#     'name': '田畑_ボイスサンプル⑥.mp3',
#     'description': '台詞6'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/田畑_ナレ①.mp3',
#     'name': '田畑_ナレ①.mp3',
#     'description': 'ナレーション'}]},
#  {'name': '中島 優衣',
#   'homepage': 'https://amuleto.jp/talents/nakajimayui.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/中島優衣.mp3',
#     'name': '中島優衣.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '中臣 真菜',
#   'homepage': 'https://amuleto.jp/talents/nakatomimana.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/中臣真菜_小学生くらい_男の子_credit.wav',
#     'name': '中臣真菜_小学生くらい_男の子_credit.wav',
#     'description': '男の子①'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/中臣真菜_小学低学年_男の子.mp3',
#     'name': '中臣真菜_小学低学年_男の子.mp3',
#     'description': '男の子②'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/中臣真菜_20代後半くらい_閑雲風.mp3',
#     'name': '中臣真菜_20代後半くらい_閑雲風.mp3',
#     'description': '女性①'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/240227_中臣真菜_外画.mp3',
#     'name': '240227_中臣真菜_外画.mp3',
#     'description': '女性②'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/中臣真菜_30代前半くらい_酒場の女性.mp3',
#     'name': '中臣真菜_30代前半くらい_酒場の女性.mp3',
#     'description': '女性③'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/中臣真菜_地声_日常系.mp3',
#     'name': '中臣真菜_地声_日常系.mp3',
#     'description': '地声'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/中臣真菜_高校生_関西弁.mp3',
#     'name': '中臣真菜_高校生_関西弁.mp3',
#     'description': '関西弁'}]},
#  {'name': '永木 さくら',
#   'homepage': 'https://amuleto.jp/talents/nagakisakura.html',
#   'sex': 'Male',
#   'voices': []},
#  {'name': '七海 とろろ',
#   'homepage': 'https://amuleto.jp/talents/nanamitororo.html',
#   'sex': 'Male',
#   'voices': []},
#  {'name': '花原 あんり',
#   'homepage': 'https://amuleto.jp/talents/hanaharaanri.html',
#   'sex': 'Male',
#   'voices': []},
#  {'name': '宮園 美海',
#   'homepage': 'https://amuleto.jp/talents/miyazonomiumi.html',
#   'sex': 'Male',
#   'voices': []},
#  {'name': '柳木 みり',
#   'homepage': 'https://amuleto.jp/talents/yanagimiri.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/柳木みりボイスサンプル.mp3',
#     'name': '柳木みりボイスサンプル.mp3',
#     'description': 'フルボイス'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/柳木みりナレーション.mp3',
#     'name': '柳木みりナレーション.mp3',
#     'description': 'ナレーション'}]},
#  {'name': '山本 亜衣',
#   'homepage': 'https://amuleto.jp/talents/yamamotoai.html',
#   'sex': 'Male',
#   'voices': []},
#  {'name': '山本 彩乃',
#   'homepage': 'https://amuleto.jp/talents/yamamotoayano.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/yamamoto.s.mp3',
#     'name': 'yamamoto.s.mp3',
#     'description': 'フルボイス'}]},
#  {'name': '吉住 絵里加',
#   'homepage': 'https://amuleto.jp/talents/yoshizumierika.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/吉住絵里加_full-online-audio-converter.com-1.mp3',
#     'name': '吉住絵里加_full-online-audio-converter.com-1.mp3',
#     'description': 'フルボイス'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/吉住絵里加_外画風_大人の女性.wav',
#     'name': '吉住絵里加_外画風_大人の女性.wav',
#     'description': '台詞1'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/吉住絵里加_戦闘系（やりあい有り）.wav',
#     'name': '吉住絵里加_戦闘系（やりあい有り）.wav',
#     'description': '台詞2'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/吉住絵里加_アニメ風_ギャルアイドル系.wav',
#     'name': '吉住絵里加_アニメ風_ギャルアイドル系.wav',
#     'description': '台詞3'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/吉住絵里加_アニメ風_10代高校生くらい上品系.wav',
#     'name': '吉住絵里加_アニメ風_10代高校生くらい上品系.wav',
#     'description': '台詞4'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/吉住絵里加_外画風_30代後半軍人上司系.wav',
#     'name': '吉住絵里加_外画風_30代後半軍人上司系.wav',
#     'description': '台詞5'},
#    {'url': 'https://amuleto.jp/renewal/wp/uploads/吉住絵里加_外画風_30代明るい笑顔な女性.wav',
#     'name': '吉住絵里加_外画風_30代明るい笑顔な女性.wav',
#     'description': '台詞6'}]},
#  {'name': '渡辺 千絢',
#   'homepage': 'https://amuleto.jp/talents/watanabechihiro.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://amuleto.jp/renewal/wp/uploads/chihiro-watanabe.mp3',
#     'name': 'chihiro-watanabe.mp3',
#     'description': 'フルボイス'}]}]

# %%
import json
with open("../jsons/hibiki.json", "w",encoding='utf-8') as f:
    json.dump(actors, f, ensure_ascii=False, indent=2)

all_voices = []
for actor in actors:
    for voice in actor["voices"]:
        all_voices.append(voice)
len(all_voices)
# Out:
# 21
