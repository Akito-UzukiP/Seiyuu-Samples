# %%
import os
import requests
from bs4 import BeautifulSoup
import json
import re
# utf-8
urls = ["https://www.kenproduction.co.jp/talent?search_voice=0&search_talent_type_id%5B%5D=2&search_talent_type_id%5B%5D=4&search_keyword=&search_prefecture_id=","https://www.kenproduction.co.jp/talent?search_voice=0&search_talent_type_id%5B%5D=1&search_talent_type_id%5B%5D=3&search_keyword=&search_prefecture_id="]


actors = []
for i, url in enumerate(urls):
    # Trust the site, no need to check the status code
    response = requests.get(url, verify=False)
    content = response.content.decode("utf-8")
    soup = BeautifulSoup(content, "html.parser")
    #print(soup)
    ul = soup.find("div", class_="search--talent--result--inner inner")
    print(len(ul.findAll("a")))
    for a in ul.findAll("a"):
        actor = {}
        actor["name"] = a.find("span").text.replace("\u3000"," ").strip()
        actor["homepage"] = a["href"]
        actor["sex"] = "Female" if i == 1 else "Male"
        actors.append(actor)
        # for a in table.find_all("a"):
        #     actor = {}       
        #     actor["name"] = a.text.replace("\u3000"," ").strip()
        #     actor["homepage"] = a["href"]
        #     actor["sex"] = "Male" if url == urls[1] else "Female"
        #     actors.append(actor)
# Out:
# 87
# 102
# [{'name': '浅利 遼太',
#   'homepage': 'https://www.kenproduction.co.jp/talent/3',
#   'sex': 'Male'},
#  {'name': '阿部 敦',
#   'homepage': 'https://www.kenproduction.co.jp/talent/249',
#   'sex': 'Male'},
#  {'name': '天野 宏郷',
#   'homepage': 'https://www.kenproduction.co.jp/talent/136',
#   'sex': 'Male'},
#  {'name': '一条 和矢',
#   'homepage': 'https://www.kenproduction.co.jp/talent/4',
#   'sex': 'Male'},
#  {'name': '稲葉 実',
#   'homepage': 'https://www.kenproduction.co.jp/talent/6',
#   'sex': 'Male'},
#  {'name': '伊原 正明',
#   'homepage': 'https://www.kenproduction.co.jp/talent/128',
#   'sex': 'Male'},
#  {'name': '岩沢 一哉',
#   'homepage': 'https://www.kenproduction.co.jp/talent/222',
#   'sex': 'Male'},
#  {'name': '梅田 修一朗',
#   'homepage': 'https://www.kenproduction.co.jp/talent/192',
#   'sex': 'Male'},
#  {'name': '江頭 宏哉',
#   'homepage': 'https://www.kenproduction.co.jp/talent/207',
#   'sex': 'Male'},
#  {'name': '遠藤 大智',
#   'homepage': 'https://www.kenproduction.co.jp/talent/11',
#   'sex': 'Male'},
#  {'name': '大隈 健太',
#   'homepage': 'https://www.kenproduction.co.jp/talent/99',
#   'sex': 'Male'},
#  {'name': '大畑 伸太郎',
#   'homepage': 'https://www.kenproduction.co.jp/talent/14',
#   'sex': 'Male'},
#  {'name': '大原 崇',
#   'homepage': 'https://www.kenproduction.co.jp/talent/15',
#   'sex': 'Male'},
#  {'name': '大町 知広',
#   'homepage': 'https://www.kenproduction.co.jp/talent/143',
#   'sex': 'Male'},
#  {'name': '小川 海斗',
#   'homepage': 'https://www.kenproduction.co.jp/talent/223',
#   'sex': 'Male'},
#  {'name': '荻野 晴朗',
#   'homepage': 'https://www.kenproduction.co.jp/talent/18',
#   'sex': 'Male'},
#  {'name': '柿田 よしくに',
#   'homepage': 'https://www.kenproduction.co.jp/talent/242',
#   'sex': 'Male'},
#  {'name': '梯 篤司',
#   'homepage': 'https://www.kenproduction.co.jp/talent/19',
#   'sex': 'Male'},
#  {'name': '勝 杏里',
#   'homepage': 'https://www.kenproduction.co.jp/talent/20',
#   'sex': 'Male'},
#  {'name': '加藤 将之',
#   'homepage': 'https://www.kenproduction.co.jp/talent/78',
#   'sex': 'Male'},
#  {'name': '烏丸 祐一',
#   'homepage': 'https://www.kenproduction.co.jp/talent/90',
#   'sex': 'Male'},
#  {'name': '河口 博',
#   'homepage': 'https://www.kenproduction.co.jp/talent/22',
#   'sex': 'Male'},
#  {'name': '河田 吉正',
#   'homepage': 'https://www.kenproduction.co.jp/talent/26',
#   'sex': 'Male'},
#  {'name': '川田 紳司',
#   'homepage': 'https://www.kenproduction.co.jp/talent/24',
#   'sex': 'Male'},
#  {'name': '観世 智顕',
#   'homepage': 'https://www.kenproduction.co.jp/talent/191',
#   'sex': 'Male'},
#  {'name': '北沢 洋',
#   'homepage': 'https://www.kenproduction.co.jp/talent/28',
#   'sex': 'Male'},
#  {'name': '北田 理道',
#   'homepage': 'https://www.kenproduction.co.jp/talent/107',
#   'sex': 'Male'},
#  {'name': '木村 太飛',
#   'homepage': 'https://www.kenproduction.co.jp/talent/224',
#   'sex': 'Male'},
#  {'name': '久賀 健治',
#   'homepage': 'https://www.kenproduction.co.jp/talent/29',
#   'sex': 'Male'},
#  {'name': '黒木 陽人',
#   'homepage': 'https://www.kenproduction.co.jp/talent/195',
#   'sex': 'Male'},
#  {'name': '小西 克幸',
#   'homepage': 'https://www.kenproduction.co.jp/talent/32',
#   'sex': 'Male'},
#  {'name': 'こぶし のぶゆき',
#   'homepage': 'https://www.kenproduction.co.jp/talent/36',
#   'sex': 'Male'},
#  {'name': '小松 昌平',
#   'homepage': 'https://www.kenproduction.co.jp/talent/130',
#   'sex': 'Male'},
#  {'name': '坂本 くんぺい',
#   'homepage': 'https://www.kenproduction.co.jp/talent/37',
#   'sex': 'Male'},
#  {'name': '相楽 信頼',
#   'homepage': 'https://www.kenproduction.co.jp/talent/108',
#   'sex': 'Male'},
#  {'name': '櫻井 トオル',
#   'homepage': 'https://www.kenproduction.co.jp/talent/84',
#   'sex': 'Male'},
#  {'name': '佐々木 拓真',
#   'homepage': 'https://www.kenproduction.co.jp/talent/132',
#   'sex': 'Male'},
#  {'name': '佐藤 拓也',
#   'homepage': 'https://www.kenproduction.co.jp/talent/39',
#   'sex': 'Male'},
#  {'name': '澤田 龍一',
#   'homepage': 'https://www.kenproduction.co.jp/talent/194',
#   'sex': 'Male'},
#  {'name': '篠原 彰宏',
#   'homepage': 'https://www.kenproduction.co.jp/talent/214',
#   'sex': 'Male'},
#  {'name': '四宮 豪',
#   'homepage': 'https://www.kenproduction.co.jp/talent/42',
#   'sex': 'Male'},
#  {'name': '志村 知幸',
#   'homepage': 'https://www.kenproduction.co.jp/talent/44',
#   'sex': 'Male'},
#  {'name': '新 祐樹',
#   'homepage': 'https://www.kenproduction.co.jp/talent/147',
#   'sex': 'Male'},
#  {'name': '仁 力',
#   'homepage': 'https://www.kenproduction.co.jp/talent/233',
#   'sex': 'Male'},
#  {'name': '菅原 雅芳',
#   'homepage': 'https://www.kenproduction.co.jp/talent/88',
#   'sex': 'Male'},
#  {'name': '鷲見 昂大',
#   'homepage': 'https://www.kenproduction.co.jp/talent/180',
#   'sex': 'Male'},
#  {'name': '高口 公介',
#   'homepage': 'https://www.kenproduction.co.jp/talent/79',
#   'sex': 'Male'},
#  {'name': '高橋 研二',
#   'homepage': 'https://www.kenproduction.co.jp/talent/48',
#   'sex': 'Male'},
#  {'name': '髙橋 孝治',
#   'homepage': 'https://www.kenproduction.co.jp/talent/118',
#   'sex': 'Male'},
#  {'name': '滝 知史',
#   'homepage': 'https://www.kenproduction.co.jp/talent/50',
#   'sex': 'Male'},
#  {'name': '田久保 修平',
#   'homepage': 'https://www.kenproduction.co.jp/talent/51',
#   'sex': 'Male'},
#  {'name': '武田 太一',
#   'homepage': 'https://www.kenproduction.co.jp/talent/197',
#   'sex': 'Male'},
#  {'name': '竹中 悠斗',
#   'homepage': 'https://www.kenproduction.co.jp/talent/243',
#   'sex': 'Male'},
#  {'name': '橘 潤二',
#   'homepage': 'https://www.kenproduction.co.jp/talent/109',
#   'sex': 'Male'},
#  {'name': '田中 光',
#   'homepage': 'https://www.kenproduction.co.jp/talent/208',
#   'sex': 'Male'},
#  {'name': '谷口 誠太郎',
#   'homepage': 'https://www.kenproduction.co.jp/talent/216',
#   'sex': 'Male'},
#  {'name': '谷山 紀章',
#   'homepage': 'https://www.kenproduction.co.jp/talent/53',
#   'sex': 'Male'},
#  {'name': '寺井 大樹',
#   'homepage': 'https://www.kenproduction.co.jp/talent/181',
#   'sex': 'Male'},
#  {'name': '中 博史',
#   'homepage': 'https://www.kenproduction.co.jp/talent/115',
#   'sex': 'Male'},
#  {'name': '中田 和宏',
#   'homepage': 'https://www.kenproduction.co.jp/talent/55',
#   'sex': 'Male'},
#  {'name': '中村 源太',
#   'homepage': 'https://www.kenproduction.co.jp/talent/205',
#   'sex': 'Male'},
#  {'name': '畠中 祐',
#   'homepage': 'https://www.kenproduction.co.jp/talent/113',
#   'sex': 'Male'},
#  {'name': '蜂須賀 智隆',
#   'homepage': 'https://www.kenproduction.co.jp/talent/92',
#   'sex': 'Male'},
#  {'name': '林 勇',
#   'homepage': 'https://www.kenproduction.co.jp/talent/58',
#   'sex': 'Male'},
#  {'name': 'はらさわ 晃綺',
#   'homepage': 'https://www.kenproduction.co.jp/talent/60',
#   'sex': 'Male'},
#  {'name': '土方 優人',
#   'homepage': 'https://www.kenproduction.co.jp/talent/63',
#   'sex': 'Male'},
#  {'name': '福西 勝也',
#   'homepage': 'https://www.kenproduction.co.jp/talent/182',
#   'sex': 'Male'},
#  {'name': '藤巻 大悟',
#   'homepage': 'https://www.kenproduction.co.jp/talent/93',
#   'sex': 'Male'},
#  {'name': '藤原 貴弘',
#   'homepage': 'https://www.kenproduction.co.jp/talent/117',
#   'sex': 'Male'},
#  {'name': '布施川 一寛',
#   'homepage': 'https://www.kenproduction.co.jp/talent/95',
#   'sex': 'Male'},
#  {'name': '古田 一晟',
#   'homepage': 'https://www.kenproduction.co.jp/talent/193',
#   'sex': 'Male'},
#  {'name': '増元 拓也',
#   'homepage': 'https://www.kenproduction.co.jp/talent/104',
#   'sex': 'Male'},
#  {'name': '益山 武明',
#   'homepage': 'https://www.kenproduction.co.jp/talent/105',
#   'sex': 'Male'},
#  {'name': '松田 修平',
#   'homepage': 'https://www.kenproduction.co.jp/talent/123',
#   'sex': 'Male'},
#  {'name': '松永 郁歩',
#   'homepage': 'https://www.kenproduction.co.jp/talent/234',
#   'sex': 'Male'},
#  {'name': '丸中 康司',
#   'homepage': 'https://www.kenproduction.co.jp/talent/217',
#   'sex': 'Male'},
#  {'name': '美斉津 恵友',
#   'homepage': 'https://www.kenproduction.co.jp/talent/198',
#   'sex': 'Male'},
#  {'name': '武蔵 真之介',
#   'homepage': 'https://www.kenproduction.co.jp/talent/152',
#   'sex': 'Male'},
#  {'name': '最上 嗣生',
#   'homepage': 'https://www.kenproduction.co.jp/talent/68',
#   'sex': 'Male'},
#  {'name': '箭内 仁',
#   'homepage': 'https://www.kenproduction.co.jp/talent/72',
#   'sex': 'Male'},
#  {'name': '矢野 智也',
#   'homepage': 'https://www.kenproduction.co.jp/talent/102',
#   'sex': 'Male'},
#  {'name': '山本 颯侍',
#   'homepage': 'https://www.kenproduction.co.jp/talent/240',
#   'sex': 'Male'},
#  {'name': '横田 大輔',
#   'homepage': 'https://www.kenproduction.co.jp/talent/141',
#   'sex': 'Male'},
#  {'name': '吉開 清人',
#   'homepage': 'https://www.kenproduction.co.jp/talent/76',
#   'sex': 'Male'},
#  {'name': '吉田 丈一郎',
#   'homepage': 'https://www.kenproduction.co.jp/talent/183',
#   'sex': 'Male'},
#  {'name': '吉原 光',
#   'homepage': 'https://www.kenproduction.co.jp/talent/209',
#   'sex': 'Male'},
#  {'name': '代永 翼',
#   'homepage': 'https://www.kenproduction.co.jp/talent/74',
#   'sex': 'Male'},
#  {'name': '相川 奈都姫',
#   'homepage': 'https://www.kenproduction.co.jp/talent/151',
#   'sex': 'Female'},
#  {'name': '逢田 梨香子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/165',
#   'sex': 'Female'},
#  {'name': '葵 あずさ',
#   'homepage': 'https://www.kenproduction.co.jp/talent/226',
#   'sex': 'Female'},
#  {'name': '綾瀬 未来',
#   'homepage': 'https://www.kenproduction.co.jp/talent/244',
#   'sex': 'Female'},
#  {'name': '池田 海咲',
#   'homepage': 'https://www.kenproduction.co.jp/talent/164',
#   'sex': 'Female'},
#  {'name': '石川 藍',
#   'homepage': 'https://www.kenproduction.co.jp/talent/210',
#   'sex': 'Female'},
#  {'name': '石松 千恵美',
#   'homepage': 'https://www.kenproduction.co.jp/talent/10',
#   'sex': 'Female'},
#  {'name': '伊藤 静',
#   'homepage': 'https://www.kenproduction.co.jp/talent/8',
#   'sex': 'Female'},
#  {'name': '伊東 みやこ',
#   'homepage': 'https://www.kenproduction.co.jp/talent/7',
#   'sex': 'Female'},
#  {'name': '稲川 英里',
#   'homepage': 'https://www.kenproduction.co.jp/talent/122',
#   'sex': 'Female'},
#  {'name': 'いのくち ゆか',
#   'homepage': 'https://www.kenproduction.co.jp/talent/12',
#   'sex': 'Female'},
#  {'name': 'イブ 優里安',
#   'homepage': 'https://www.kenproduction.co.jp/talent/166',
#   'sex': 'Female'},
#  {'name': '漆山 ゆうき',
#   'homepage': 'https://www.kenproduction.co.jp/talent/211',
#   'sex': 'Female'},
#  {'name': '遠藤 さき',
#   'homepage': 'https://www.kenproduction.co.jp/talent/227',
#   'sex': 'Female'},
#  {'name': '大熊 和奏',
#   'homepage': 'https://www.kenproduction.co.jp/talent/247',
#   'sex': 'Female'},
#  {'name': '鳳 芳野',
#   'homepage': 'https://www.kenproduction.co.jp/talent/16',
#   'sex': 'Female'},
#  {'name': '小笠原 早紀',
#   'homepage': 'https://www.kenproduction.co.jp/talent/135',
#   'sex': 'Female'},
#  {'name': '荻野 佳奈',
#   'homepage': 'https://www.kenproduction.co.jp/talent/228',
#   'sex': 'Female'},
#  {'name': '甲斐田 裕子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/21',
#   'sex': 'Female'},
#  {'name': '鷄冠井 美智子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/154',
#   'sex': 'Female'},
#  {'name': 'かどたに まみ',
#   'homepage': 'https://www.kenproduction.co.jp/talent/185',
#   'sex': 'Female'},
#  {'name': 'かない みか',
#   'homepage': 'https://www.kenproduction.co.jp/talent/23',
#   'sex': 'Female'},
#  {'name': '金田 愛',
#   'homepage': 'https://www.kenproduction.co.jp/talent/200',
#   'sex': 'Female'},
#  {'name': '川上 彩',
#   'homepage': 'https://www.kenproduction.co.jp/talent/170',
#   'sex': 'Female'},
#  {'name': '川端 麻衣',
#   'homepage': 'https://www.kenproduction.co.jp/talent/137',
#   'sex': 'Female'},
#  {'name': '稀代 桜子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/248',
#   'sex': 'Female'},
#  {'name': '北原 沙弥香',
#   'homepage': 'https://www.kenproduction.co.jp/talent/172',
#   'sex': 'Female'},
#  {'name': '城戸 まどか',
#   'homepage': 'https://www.kenproduction.co.jp/talent/201',
#   'sex': 'Female'},
#  {'name': '喜代原 まり',
#   'homepage': 'https://www.kenproduction.co.jp/talent/155',
#   'sex': 'Female'},
#  {'name': '高野 菜々',
#   'homepage': 'https://www.kenproduction.co.jp/talent/161',
#   'sex': 'Female'},
#  {'name': '古城門 志帆',
#   'homepage': 'https://www.kenproduction.co.jp/talent/140',
#   'sex': 'Female'},
#  {'name': '小白川 愛菜',
#   'homepage': 'https://www.kenproduction.co.jp/talent/218',
#   'sex': 'Female'},
#  {'name': '小平 有希',
#   'homepage': 'https://www.kenproduction.co.jp/talent/33',
#   'sex': 'Female'},
#  {'name': '木花 藍',
#   'homepage': 'https://www.kenproduction.co.jp/talent/245',
#   'sex': 'Female'},
#  {'name': '小橋 知子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/31',
#   'sex': 'Female'},
#  {'name': '小林 未沙',
#   'homepage': 'https://www.kenproduction.co.jp/talent/111',
#   'sex': 'Female'},
#  {'name': '小堀 幸',
#   'homepage': 'https://www.kenproduction.co.jp/talent/157',
#   'sex': 'Female'},
#  {'name': '合田 絵利',
#   'homepage': 'https://www.kenproduction.co.jp/talent/110',
#   'sex': 'Female'},
#  {'name': '後藤 麻衣',
#   'homepage': 'https://www.kenproduction.co.jp/talent/98',
#   'sex': 'Female'},
#  {'name': '斎賀 みつき',
#   'homepage': 'https://www.kenproduction.co.jp/talent/35',
#   'sex': 'Female'},
#  {'name': '齋藤 綾',
#   'homepage': 'https://www.kenproduction.co.jp/talent/158',
#   'sex': 'Female'},
#  {'name': 'さとう あい',
#   'homepage': 'https://www.kenproduction.co.jp/talent/38',
#   'sex': 'Female'},
#  {'name': '渋谷 彩乃',
#   'homepage': 'https://www.kenproduction.co.jp/talent/169',
#   'sex': 'Female'},
#  {'name': '嶋崎 はるか',
#   'homepage': 'https://www.kenproduction.co.jp/talent/41',
#   'sex': 'Female'},
#  {'name': '嶋村 侑',
#   'homepage': 'https://www.kenproduction.co.jp/talent/43',
#   'sex': 'Female'},
#  {'name': '清水 はる香',
#   'homepage': 'https://www.kenproduction.co.jp/talent/162',
#   'sex': 'Female'},
#  {'name': '〆野 潤子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/45',
#   'sex': 'Female'},
#  {'name': '下田 岺易',
#   'homepage': 'https://www.kenproduction.co.jp/talent/47',
#   'sex': 'Female'},
#  {'name': '下山田 綾華',
#   'homepage': 'https://www.kenproduction.co.jp/talent/119',
#   'sex': 'Female'},
#  {'name': '社本 悠',
#   'homepage': 'https://www.kenproduction.co.jp/talent/241',
#   'sex': 'Female'},
#  {'name': '白川 万紗子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/112',
#   'sex': 'Female'},
#  {'name': '新藤 みなみ',
#   'homepage': 'https://www.kenproduction.co.jp/talent/236',
#   'sex': 'Female'},
#  {'name': '末柄 里恵',
#   'homepage': 'https://www.kenproduction.co.jp/talent/142',
#   'sex': 'Female'},
#  {'name': '菅沼 千紗',
#   'homepage': 'https://www.kenproduction.co.jp/talent/173',
#   'sex': 'Female'},
#  {'name': '鈴木 弘子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/52',
#   'sex': 'Female'},
#  {'name': '鷹雄 葉月',
#   'homepage': 'https://www.kenproduction.co.jp/talent/213',
#   'sex': 'Female'},
#  {'name': '高橋 里枝',
#   'homepage': 'https://www.kenproduction.co.jp/talent/56',
#   'sex': 'Female'},
#  {'name': '竹島 レナ',
#   'homepage': 'https://www.kenproduction.co.jp/talent/237',
#   'sex': 'Female'},
#  {'name': '津田 匠子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/57',
#   'sex': 'Female'},
#  {'name': '寺崎 裕香',
#   'homepage': 'https://www.kenproduction.co.jp/talent/232',
#   'sex': 'Female'},
#  {'name': '藤堂 真衣',
#   'homepage': 'https://www.kenproduction.co.jp/talent/129',
#   'sex': 'Female'},
#  {'name': '富樫 美鈴',
#   'homepage': 'https://www.kenproduction.co.jp/talent/163',
#   'sex': 'Female'},
#  {'name': '冨田 泰代',
#   'homepage': 'https://www.kenproduction.co.jp/talent/114',
#   'sex': 'Female'},
#  {'name': '友川 まり',
#   'homepage': 'https://www.kenproduction.co.jp/talent/59',
#   'sex': 'Female'},
#  {'name': '百々 麻子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/61',
#   'sex': 'Female'},
#  {'name': '内藤 有海',
#   'homepage': 'https://www.kenproduction.co.jp/talent/126',
#   'sex': 'Female'},
#  {'name': '中村 知子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/100',
#   'sex': 'Female'},
#  {'name': '永井 真里子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/174',
#   'sex': 'Female'},
#  {'name': '夏見 涼子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/238',
#   'sex': 'Female'},
#  {'name': '夏吉 ゆうこ',
#   'homepage': 'https://www.kenproduction.co.jp/talent/202',
#   'sex': 'Female'},
#  {'name': '生天目 仁美',
#   'homepage': 'https://www.kenproduction.co.jp/talent/66',
#   'sex': 'Female'},
#  {'name': '西墻 由香',
#   'homepage': 'https://www.kenproduction.co.jp/talent/67',
#   'sex': 'Female'},
#  {'name': '野中 民美代',
#   'homepage': 'https://www.kenproduction.co.jp/talent/69',
#   'sex': 'Female'},
#  {'name': '野村 麻衣子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/176',
#   'sex': 'Female'},
#  {'name': '長谷川 暖',
#   'homepage': 'https://www.kenproduction.co.jp/talent/167',
#   'sex': 'Female'},
#  {'name': 'はやみ けい',
#   'homepage': 'https://www.kenproduction.co.jp/talent/71',
#   'sex': 'Female'},
#  {'name': 'ハートル 実沙',
#   'homepage': 'https://www.kenproduction.co.jp/talent/219',
#   'sex': 'Female'},
#  {'name': 'ひと美',
#   'homepage': 'https://www.kenproduction.co.jp/talent/73',
#   'sex': 'Female'},
#  {'name': '日野 未歩',
#   'homepage': 'https://www.kenproduction.co.jp/talent/77',
#   'sex': 'Female'},
#  {'name': '平井 祥恵',
#   'homepage': 'https://www.kenproduction.co.jp/talent/120',
#   'sex': 'Female'},
#  {'name': '平松 晶子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/75',
#   'sex': 'Female'},
#  {'name': '廣瀬 仁美',
#   'homepage': 'https://www.kenproduction.co.jp/talent/80',
#   'sex': 'Female'},
#  {'name': '弘松 芹香',
#   'homepage': 'https://www.kenproduction.co.jp/talent/177',
#   'sex': 'Female'},
#  {'name': '福島 桂子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/83',
#   'sex': 'Female'},
#  {'name': '藤田 茜',
#   'homepage': 'https://www.kenproduction.co.jp/talent/131',
#   'sex': 'Female'},
#  {'name': '藤村 歩',
#   'homepage': 'https://www.kenproduction.co.jp/talent/85',
#   'sex': 'Female'},
#  {'name': '舩津丸 葵',
#   'homepage': 'https://www.kenproduction.co.jp/talent/220',
#   'sex': 'Female'},
#  {'name': '松村 淑子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/87',
#   'sex': 'Female'},
#  {'name': '松元 惠',
#   'homepage': 'https://www.kenproduction.co.jp/talent/89',
#   'sex': 'Female'},
#  {'name': '丸山 有香',
#   'homepage': 'https://www.kenproduction.co.jp/talent/146',
#   'sex': 'Female'},
#  {'name': '三浦 千幸',
#   'homepage': 'https://www.kenproduction.co.jp/talent/203',
#   'sex': 'Female'},
#  {'name': '三日尻 望',
#   'homepage': 'https://www.kenproduction.co.jp/talent/188',
#   'sex': 'Female'},
#  {'name': '三川 華月',
#   'homepage': 'https://www.kenproduction.co.jp/talent/221',
#   'sex': 'Female'},
#  {'name': '宮古 風佳',
#   'homepage': 'https://www.kenproduction.co.jp/talent/246',
#   'sex': 'Female'},
#  {'name': '望月 ゆみこ',
#   'homepage': 'https://www.kenproduction.co.jp/talent/239',
#   'sex': 'Female'},
#  {'name': '森 彩香',
#   'homepage': 'https://www.kenproduction.co.jp/talent/231',
#   'sex': 'Female'},
#  {'name': '森谷 彩子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/204',
#   'sex': 'Female'},
#  {'name': '屋根下 怜生',
#   'homepage': 'https://www.kenproduction.co.jp/talent/229',
#   'sex': 'Female'},
#  {'name': '山口 享佑子',
#   'homepage': 'https://www.kenproduction.co.jp/talent/94',
#   'sex': 'Female'},
#  {'name': '山崎 みちる',
#   'homepage': 'https://www.kenproduction.co.jp/talent/96',
#   'sex': 'Female'},
#  {'name': '吉澤 悠',
#   'homepage': 'https://www.kenproduction.co.jp/talent/230',
#   'sex': 'Female'},
#  {'name': '渡辺 理沙',
#   'homepage': 'https://www.kenproduction.co.jp/talent/189',
#   'sex': 'Female'}]

# %%
len(actors)
# Out:
# 189

# %%
import re
def get_voices(homepage:str):
    response = requests.get(homepage, verify=False)
    content = response.content.decode("utf-8")
    soup = BeautifulSoup(content, "html.parser")
    print(soup)
    voices = []
    voice_samples = soup.findAll("li", class_="voiceTab")
    for voice_sample in voice_samples:
        for li in voice_sample.findAll("li"):
            voice = {}
            voice["url"] = "https://www.kenproduction.co.jp"+li.find("source")["src"]
            voice["name"] = voice["url"].split("/")[-1]
            voice["description"] = "サンプルボイス"
            voices.append(voice)
    return voices

#get_voices("https://mausu.net/talent/anzai-kazuhiro.html")

import tqdm
pbar = tqdm.tqdm(actors)
for actor in pbar:
    actor["voices"] = get_voices(actor["homepage"])
    pbar.set_description(str(len(actor["voices"])))
actors
# Out:
# 1:   3%|▎         | 1/34 [00:00<00:14,  2.33it/s]
# <!DOCTYPE html>
#
# <html class="agency" lang="ja" prefix="og: http://ogp.me/ns#" xml:lang="ja" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, user-scalable=yes" name="viewport"/>
# <title>安斉 一博 | 所属タレント | マウスプロモーション</title>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" name="description"/>
# <meta content="マウスプロモーション, マウスプロモーション附属俳優養成所, 俳優養成所, スタジオマウス, マウスショップ, 江崎, プロダクション, 声優, 養成所, MAUSU PROMOTION, STUDIO MAUSU" name="keywords"/>
# <link href="https://mausu.net/" rel="index" title="マウスプロモーション"/>
# <link href="/talent/anzai-kazuhiro_print.html" media="print" rel="alternate" title="For Printing"/>
# <meta content="article" property="og:type"/>
# <meta content="安斉 一博 | 所属タレント | マウスプロモーション" property="og:title"/>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" property="og:description"/>
# <meta content="https://mausu.net/talent/content/images/056.jpg" property="og:image"/>
# <meta content="https://mausu.net/talent/anzai-kazuhiro.html" property="og:url"/>
# <meta content="マウスプロモーション" property="og:site_name"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="mausu.net" name="twitter:domain"/>
# <meta content="安斉 一博 | 所属タレント | マウスプロモーション" name="twitter:title"/>
# <meta content="https://mausu.net/talent/anzai-kazuhiro.html" name="twitter:url"/>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" name="twitter:description"/>
# <meta content="https://mausu.net/talent/content/images/056.jpg" name="twitter:image"/>
# <link href="/res/styles/mausu.css" rel="stylesheet"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-TF4G822');</script>
# <!-- End Google Tag Manager -->
# <script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 	ga('create', 'UA-81196363-1', 'auto');
# 	ga('send', 'pageview');
# 	</script>
# <script src="/res/scripts/mausu.js"></script>
# <link href="https://fonts.googleapis.com/css?family=M+PLUS+Rounded+1c:700&amp;display=swap" rel="stylesheet"/>
# <link href="/res/images/common/clipicon.png" rel="apple-touch-icon">
# <link href="/res/images/common/clipicon.png" rel="apple-touch-icon-precomposed"/>
# <link href="/res/images/common/favicon.ico" rel="shortcut icon"/>
# <dt>CDドラマ</dt>
# <dd>「戦国BASARA2 蒼穹！姉川の戦い」<br/>「エンジェルズ・フェザー2」（ロジオン）<br/>「俺の兄貴に手を出すな」（高柳伊知郎）<br/>「花嫁は緋色に囚われる」（警備員）<br/>「花帰葬 夢を視る化石／Typing Of Th eChicken」（彼草）<br/>「北の漁場」（2007年、組員）<br/>「セーラー服は誰が着る？！」<br/>「L Heure Bleue」<br/>「王ドロボウJINGエル・スール」<br/>「九龍妖魔学園紀2」</dd>
# </dl>
# </td>
# </tr>
# </tbody>
# </table>
# <div class="pgroup">
# <p><a data-style-variation="button" href="/talent/male/">男性タレント一覧へ</a></p>
# </div>
# <section class="fan-letter">
# <div class="hgroup">
# <h2>ファンレター送付先</h2>
# </div>
# <div class="pgroup">
# <p>ファンレターはタレント名を記載して、事務所宛にお送りください。</p>
# <p><small><span class="marker">※</span> 事務所宛ファンメールの受付は、基本的には行っておりませんのでご了承ください。</small></p>
# </div>
# <div class="pgroup">
# <p><a data-style-variation="button" href="/fan-letter/">送付先</a></p>
# </div>
# </section>
# </article>
# </main>
# <aside id="page-complementary" role="complementary">
# <ul class="parallel-list" data-style-variation="cols-3-3-3-3">
# <li><a href="/shop/original-anime/"><img alt="オリジナルアニメ マウスどうぶつえん" src="/content/images/common/banner_original-anime.png"/></a></li>
# <li><a href="/school/"><img alt="本気で声優めざすなら マウスプロモーション附属俳優養成所" src="/content/images/common/banner_school.png"/></a></li>
# <li><a href="http://www.amazon.co.jp/dp/4061385895" target="_blank"><img alt="大塚明夫の声優塾" src="/content/images/common/banner_seiyujuku.png"/></a></li>
# <li><a href="/shop/"><img alt="マウスショップ" src="/content/images/common/banner_shop.png"/></a></li>
# </ul>
# </aside>
# <footer id="page-footer" role="contentinfo">
# <aside>
# <ul>
# <li><a href="/about/#overview">会社概要</a></li>
# <li><a href="/#contact">お問い合わせ</a></li>
# <li><a href="/privacy/">プライバシーポリシー</a></li>
# <li><a href="/legal/">ご利用規約</a></li>
# </ul>
# <div class="pgroup">
# <address>© <a href="/">株式会社マウスプロモーション</a></address>
# </div>
# </aside>
# </footer>
# </body>
# </html>
# 1:   6%|▌         | 2/34 [00:00<00:13,  2.37it/s]
# <!DOCTYPE html>
#
# <html class="agency" lang="ja" prefix="og: http://ogp.me/ns#" xml:lang="ja" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, user-scalable=yes" name="viewport"/>
# <title>石上 裕一 | 所属タレント | マウスプロモーション</title>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" name="description"/>
# <meta content="マウスプロモーション, マウスプロモーション附属俳優養成所, 俳優養成所, スタジオマウス, マウスショップ, 江崎, プロダクション, 声優, 養成所, MAUSU PROMOTION, STUDIO MAUSU" name="keywords"/>
# <link href="https://mausu.net/" rel="index" title="マウスプロモーション"/>
# <link href="/talent/ishigami-yuichi_print.html" media="print" rel="alternate" title="For Printing"/>
# <meta content="article" property="og:type"/>
# <meta content="石上 裕一 | 所属タレント | マウスプロモーション" property="og:title"/>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" property="og:description"/>
# <meta content="https://mausu.net/talent/content/images/057.jpg" property="og:image"/>
# <meta content="https://mausu.net/talent/ishigami-yuichi.html" property="og:url"/>
# <meta content="マウスプロモーション" property="og:site_name"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="mausu.net" name="twitter:domain"/>
# <meta content="石上 裕一 | 所属タレント | マウスプロモーション" name="twitter:title"/>
# <meta content="https://mausu.net/talent/ishigami-yuichi.html" name="twitter:url"/>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" name="twitter:description"/>
# <meta content="https://mausu.net/talent/content/images/057.jpg" name="twitter:image"/>
# <link href="/res/styles/mausu.css" rel="stylesheet"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-TF4G822');</script>
# <!-- End Google Tag Manager -->
# <script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 	ga('create', 'UA-81196363-1', 'auto');
# 	ga('send', 'pageview');
# 	</script>
# <script src="/res/scripts/mausu.js"></script>
# <link href="https://fonts.googleapis.com/css?family=M+PLUS+Rounded+1c:700&amp;display=swap" rel="stylesheet"/>
# <link href="/res/images/common/clipicon.png" rel="apple-touch-icon">
# <link href="/res/images/common/clipicon.png" rel="apple-touch-icon-precomposed"/>
# <link href="/res/images/common/favicon.ico" rel="shortcut icon"/>
# </link></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TF4G822" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header id="page-header" role="banner">
# <div class="hgroup" id="site-id">
# <h1 class="agency"><a href="/"><img alt="マウスプロモーション | Mausu Promotion" height="38" src="/res/images/common/logo-agency.svg"/></a></h1>
# </div>
# <nav id="global-nav" role="navigation">
# <input id="global-nav-switch" name="global-nav-switch" type="checkbox"/><label for="global-nav-switch">メニュー</label>
# <ul>
# <dt>CDドラマ</dt>
# <dd> 「B.A.D.嗤う髑髏」（杉田智之）<br/> 「俺様ティーチャー」（ネコマタ）<br/> 「幸福喫茶３丁目」（少女の父親）<br/> 「花嫁衣裳は誰が着る!?」</dd>
# <dt>その他</dt>
# <dd>特撮 <br/>「仮面ライダーキバ」（シームーンファンガイア）<br/><br/>ラジオドラマ<br/> 「VOMIC コイバナ！～恋せよ花火～」（久保惣太郎）<br/><br/>パチンコ・パチスロ<br/> 「CR忍魂」（Dr.マッド）<br/> 「忍魂弐～烈火ノ章～」（マッド改）</dd>
# </dl>
# </td>
# </tr>
# </tbody>
# </table>
# <div class="pgroup">
# <p><a data-style-variation="button" href="/talent/male/">男性タレント一覧へ</a></p>
# </div>
# <section class="fan-letter">
# <div class="hgroup">
# <h2>ファンレター送付先</h2>
# </div>
# <div class="pgroup">
# <p>ファンレターはタレント名を記載して、事務所宛にお送りください。</p>
# <p><small><span class="marker">※</span> 事務所宛ファンメールの受付は、基本的には行っておりませんのでご了承ください。</small></p>
# </div>
# <div class="pgroup">
# <p><a data-style-variation="button" href="/fan-letter/">送付先</a></p>
# </div>
# </section>
# </article>
# </main>
# <aside id="page-complementary" role="complementary">
# <ul class="parallel-list" data-style-variation="cols-3-3-3-3">
# <li><a href="/shop/original-anime/"><img alt="オリジナルアニメ マウスどうぶつえん" src="/content/images/common/banner_original-anime.png"/></a></li>
# <li><a href="/school/"><img alt="本気で声優めざすなら マウスプロモーション附属俳優養成所" src="/content/images/common/banner_school.png"/></a></li>
# <li><a href="http://www.amazon.co.jp/dp/4061385895" target="_blank"><img alt="大塚明夫の声優塾" src="/content/images/common/banner_seiyujuku.png"/></a></li>
# <li><a href="/shop/"><img alt="マウスショップ" src="/content/images/common/banner_shop.png"/></a></li>
# </ul>
# </aside>
# <footer id="page-footer" role="contentinfo">
# <aside>
# <ul>
# <li><a href="/about/#overview">会社概要</a></li>
# <li><a href="/#contact">お問い合わせ</a></li>
# <li><a href="/privacy/">プライバシーポリシー</a></li>
# <li><a href="/legal/">ご利用規約</a></li>
# </ul>
# <div class="pgroup">
# <address>© <a href="/">株式会社マウスプロモーション</a></address>
# </div>
# </aside>
# </footer>
# </body>
# </html>
# 1:   9%|▉         | 3/34 [00:01<00:12,  2.42it/s]
# <!DOCTYPE html>
#
# <html class="agency" lang="ja" prefix="og: http://ogp.me/ns#" xml:lang="ja" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, user-scalable=yes" name="viewport"/>
# <title>市来 光弘 | 所属タレント | マウスプロモーション</title>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" name="description"/>
# <meta content="マウスプロモーション, マウスプロモーション附属俳優養成所, 俳優養成所, スタジオマウス, マウスショップ, 江崎, プロダクション, 声優, 養成所, MAUSU PROMOTION, STUDIO MAUSU" name="keywords"/>
# <link href="https://mausu.net/" rel="index" title="マウスプロモーション"/>
# <link href="/talent/ichiki-mitsuhiro_print.html" media="print" rel="alternate" title="For Printing"/>
# <meta content="article" property="og:type"/>
# <meta content="市来 光弘 | 所属タレント | マウスプロモーション" property="og:title"/>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" property="og:description"/>
# <meta content="https://mausu.net/talent/content/images/116.jpg" property="og:image"/>
# <meta content="https://mausu.net/talent/ichiki-mitsuhiro.html" property="og:url"/>
# <meta content="マウスプロモーション" property="og:site_name"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="mausu.net" name="twitter:domain"/>
# <meta content="市来 光弘 | 所属タレント | マウスプロモーション" name="twitter:title"/>
# <meta content="https://mausu.net/talent/ichiki-mitsuhiro.html" name="twitter:url"/>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" name="twitter:description"/>
# <meta content="https://mausu.net/talent/content/images/116.jpg" name="twitter:image"/>
# <link href="/res/styles/mausu.css" rel="stylesheet"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-TF4G822');</script>
# <!-- End Google Tag Manager -->
# <script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 	ga('create', 'UA-81196363-1', 'auto');
# 	ga('send', 'pageview');
# 	</script>
# <script src="/res/scripts/mausu.js"></script>
# <link href="https://fonts.googleapis.com/css?family=M+PLUS+Rounded+1c:700&amp;display=swap" rel="stylesheet"/>
# <link href="/res/images/common/clipicon.png" rel="apple-touch-icon">
# <link href="/res/images/common/clipicon.png" rel="apple-touch-icon-precomposed"/>
# <link href="/res/images/common/favicon.ico" rel="shortcut icon"/>
# </link></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TF4G822" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header id="page-header" role="banner">
# <div class="hgroup" id="site-id">
# <h1 class="agency"><a href="/"><img alt="マウスプロモーション | Mausu Promotion" height="38" src="/res/images/common/logo-agency.svg"/></a></h1>
# </div>
# <nav id="global-nav" role="navigation">
# <input id="global-nav-switch" name="global-nav-switch" type="checkbox"/><label for="global-nav-switch">メニュー</label>
# <ul>
# <dt>出身地</dt>
# <dd>鹿児島</dd>
# <dt>方言</dt>
# <dd>-</dd>
# <dt>趣味・特技</dt>
# <dd>料理・格闘ゲーム</dd>
# <dt class="non-visual">関連ウェブサイト</dt>
# <dd>
# <ul>
# <li><a data-style-variation="icon website" href="http://ameblo.jp/garoumow/" rel="external" target="_blank">Website</a></li>
# <li><a data-style-variation="icon twitter" href="https://twitter.com/mitsuhiroichiki" rel="external" target="_blank">Twitter</a></li>
# </ul>
# </dd>
# </dl>
# <table>
# <tbody>
# <tr>
# <th scope="row">経歴</th>
# <td>平成14年：元気プロジェクト所属<br/>平成21年：マウスプロモーション所属</td>
# </tr>
# <tr>
# <th scope="row">主な出演作品</th>
# <td>
# <dl>
# <dt>アニメ</dt>
# <dd>「刀剣乱舞-花丸-」（大和守安定）<br/>「続・刀剣乱舞-花丸-」（大和守安定）<br/>「佐々木と宮野」（田代権三郎）<br/>「八十亀ちゃんかんさつにっき」（陣界斗）<br/>「鬼滅の刃」（正一）<br/>「踏切時間」（駒場たかし）<br/>「バジリスク桜花忍法帖」（蜩七弦）<br/>「A3！」(飛鳥晴翔)<br/>「新幹線変形ロボ シンカリオン」(霧島タカトラ)<br/>「ドロヘドロ」(カスカベ)<br/>「バーナード嬢曰く。」（遠藤）<br/>「D.Gray-man HALLOW」（ジョニー・ギル）<br/>「探偵チームKZ事件ノート」（小塚和彦）<br/>「BLEACH」（雪緒）<br/>「フリージング」（アオイ=カズヤ）<br/>「会長はメイド様！」（白川直也）<br/>「マリア様がみてる」（福沢祐麒）<br/>「スクールランブル」（麻生広義）<br/>「南の島の小さな飛行機バーディ」（ビー）<br/>「うえきの法則」（山田八十吉）<br/>「S･A～スペシャル･エー～」（華園亮）<br/>「天対戦士サンレッド」（ナイトマン）<br/>「お兄ちゃんのことなんかぜんぜん好きじゃないんだからねっ!!」（黒崎大吾）</dd>
# <dt>ゲーム</dt>
# <dd>「刀剣乱舞-ONLINE-」（大和守安定）<br/>「グランブルーファンタジー」（イカロス）<br/>「OZMAFIA!!」（スカーレット）<br/>「デザート・キングダム ポータブル」（レジェッタ・サマル）<br/>「ブレイブルー クロノファンタズマ」（ヒビキ・コハク）<br/>「ファイアーエムブレム 覚醒」（ドニ）<br/>「メルルのアトリエ ～アーランドの錬金術師3～」（ライアス・フォールケン）<br/>「迷宮塔路レガシスタ」（アルト・ストレイター）<br/>「ときめきメモリアル Girl's Side Premium～３rd Story～」（大迫力）<br/>「ルートダブル～before crime after days～」（天川夏彦）<br/>「流星☆ハレーション」（マーベル・朝日）</dd>
# <dt>吹き替え</dt>
# <dd>「アーチボルトの大冒険」(アーチボルト)<br/>「ベン10エイリアン・フォース」（アラン/ヒートブラスト役）<br/>「アリス アップサイド ダウン」（パトリック）<br/>「卒業の朝」<br/>「ハリー・ポッターと炎のゴブレット」</dd>
# <dt>舞台</dt>
# <dd>「青春ゲットバック」（ポール役）</dd>
# </dl>
# </td>
# </tr>
# </tbody>
# </table>
# <div class="pgroup">
# <p><a data-style-variation="button" href="/talent/male/">男性タレント一覧へ</a></p>
# </div>
# <section class="fan-letter">
# <div class="hgroup">
# <h2>ファンレター送付先</h2>
# </div>
# <div class="pgroup">
# <p>ファンレターはタレント名を記載して、事務所宛にお送りください。</p>
# <p><small><span class="marker">※</span> 事務所宛ファンメールの受付は、基本的には行っておりませんのでご了承ください。</small></p>
# </div>
# <div class="pgroup">
# <p><a data-style-variation="button" href="/fan-letter/">送付先</a></p>
# </div>
# </section>
# </article>
# </main>
# <aside id="page-complementary" role="complementary">
# <ul class="parallel-list" data-style-variation="cols-3-3-3-3">
# <li><a href="/shop/original-anime/"><img alt="オリジナルアニメ マウスどうぶつえん" src="/content/images/common/banner_original-anime.png"/></a></li>
# <li><a href="/school/"><img alt="本気で声優めざすなら マウスプロモーション附属俳優養成所" src="/content/images/common/banner_school.png"/></a></li>
# <li><a href="http://www.amazon.co.jp/dp/4061385895" target="_blank"><img alt="大塚明夫の声優塾" src="/content/images/common/banner_seiyujuku.png"/></a></li>
# <li><a href="/shop/"><img alt="マウスショップ" src="/content/images/common/banner_shop.png"/></a></li>
# </ul>
# </aside>
# <footer id="page-footer" role="contentinfo">
# <aside>
# <ul>
# <li><a href="/about/#overview">会社概要</a></li>
# <li><a href="/#contact">お問い合わせ</a></li>
# <li><a href="/privacy/">プライバシーポリシー</a></li>
# <li><a href="/legal/">ご利用規約</a></li>
# </ul>
# <div class="pgroup">
# <address>© <a href="/">株式会社マウスプロモーション</a></address>
# </div>
# </aside>
# </footer>
# </body>
# </html>
# 1:  12%|█▏        | 4/34 [00:01<00:12,  2.49it/s]
# <!DOCTYPE html>
#
# <html class="agency" lang="ja" prefix="og: http://ogp.me/ns#" xml:lang="ja" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, user-scalable=yes" name="viewport"/>
# <title>伊藤 健太郎 | 所属タレント | マウスプロモーション</title>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" name="description"/>
# <meta content="マウスプロモーション, マウスプロモーション附属俳優養成所, 俳優養成所, スタジオマウス, マウスショップ, 江崎, プロダクション, 声優, 養成所, MAUSU PROMOTION, STUDIO MAUSU" name="keywords"/>
# <link href="https://mausu.net/" rel="index" title="マウスプロモーション"/>
# <link href="/talent/ito-kentaro_print.html" media="print" rel="alternate" title="For Printing"/>
# <meta content="article" property="og:type"/>
# <meta content="伊藤 健太郎 | 所属タレント | マウスプロモーション" property="og:title"/>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" property="og:description"/>
# <meta content="https://mausu.net/talent/content/images/118.jpg" property="og:image"/>
# <meta content="https://mausu.net/talent/ito-kentaro.html" property="og:url"/>
# <meta content="マウスプロモーション" property="og:site_name"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="mausu.net" name="twitter:domain"/>
# <meta content="伊藤 健太郎 | 所属タレント | マウスプロモーション" name="twitter:title"/>
# <meta content="https://mausu.net/talent/ito-kentaro.html" name="twitter:url"/>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" name="twitter:description"/>
# <meta content="https://mausu.net/talent/content/images/118.jpg" name="twitter:image"/>
# <link href="/res/styles/mausu.css" rel="stylesheet"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-TF4G822');</script>
# <!-- End Google Tag Manager -->
# <script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 	ga('create', 'UA-81196363-1', 'auto');
# 	ga('send', 'pageview');
# 	</script>
# <script src="/res/scripts/mausu.js"></script>
# <link href="https://fonts.googleapis.com/css?family=M+PLUS+Rounded+1c:700&amp;display=swap" rel="stylesheet"/>
# <link href="/res/images/common/clipicon.png" rel="apple-touch-icon">
# <link href="/res/images/common/clipicon.png" rel="apple-touch-icon-precomposed"/>
# <link href="/res/images/common/favicon.ico" rel="shortcut icon"/>
# </link></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TF4G822" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header id="page-header" role="banner">
# <div class="hgroup" id="site-id">
# <h1 class="agency"><a href="/"><img alt="マウスプロモーション | Mausu Promotion" height="38" src="/res/images/common/logo-agency.svg"/></a></h1>
# </div>
# <nav id="global-nav" role="navigation">
# <input id="global-nav-switch" name="global-nav-switch" type="checkbox"/><label for="global-nav-switch">メニュー</label>
# <ul>
# <li class="agency"><a href="/"><span>マウスプロモーション</span></a>
# <ul>
# <li><a href="/about/"><span>マウスプロモーションについて</span></a></li>
# <li><a href="/talent/female/"><span>女性タレント</span></a></li>
# <li><a href="/talent/male/"><span>男性タレント</span></a></li>
# <li><a href="/topics/"><span>トピックス</span></a></li>
# <li><a href="/appearance/"><span>出演情報</span></a></li>
# </ul>
# <ul>
# <li><a href="/#contact"><span>お問い合わせ</span></a></li>
# <li><a href="/about/#access"><span>アクセス</span></a></li>
# </ul>
# </li>
# <li class="school"><a href="/school/"><span>マウスプロモーション</span><span>附属俳優養成所</span></a>
# <ul>
# <li><a href="/school/introduction.html"><span>授業内容</span></a></li>
# <li><a href="/school/teacher.html"><span>講師紹介</span></a></li>
# <li><a href="/school/graduate.html"><span>卒業生紹介</span></a></li>
# <li><a href="/school/scene.html"><span>授業風景</span></a></li>
# <li><a href="/school/fee.html"><span>授業料</span></a></li>
# <li><a href="/school/faq.html"><span>Q&amp;A</span></a></li>
# <li><a href="/school/applicants.html"><span>募集要項／入所の流れ</span></a></li>
# </ul>
# <ul>
# <li><a href="/school/contact.html"><span>お問い合わせ</span></a></li>
# </ul>
# </li>
# <li class="studio"><a href="/studio/"><span>スタジオマウス</span></a>
# <ul>
# <li><a href="/studio/about/"><span>スタジオマウスについて</span></a></li>
# <li><a href="/studio/studio1st.html"><span>Studio 1st.</span></a></li>
# <li><a href="/studio/studio2nd.html"><span>Studio 2nd.</span></a></li>
# <li><a href="/studio/works/"><span>作品リスト</span></a></li>
# </ul>
# <ul>
# <li><a href="/studio/#access"><span>アクセス</span></a></li>
# </ul>
# </li>
# <li class="shop"><a href="/shop/"><span>マウスショップ</span></a>
# <ul>
# <li><a href="/shop/about/"><span>マウスショップとは</span></a></li>
# <li><a href="/shop/event-info/"><span>イベント情報／お知らせ</span></a></li>
# <li><a href="/shop/original-anime/"><span>マウスどうぶつえん</span></a></li>
# <li><a href="/shop/original-goods"><span>オリジナルグッズ</span></a></li>
# </ul>
# <ul>
# <li><a href="/shop/original-anime/about/"><span>キャラ一覧</span></a></li>
# <li><a href="/shop/#access"><span>アクセス</span></a></li>
# </ul>
# </li>
# </ul>
# </nav>
# </header>
# <main id="page-content" role="main">
# <article class="actor" id="ito-kentaro">
# <div class="figgroup">
# <figure><span class="person-image"><img alt="伊藤 健太郎 肖像写真" src="/talent/content/118.jpg"/></span></figure>
# </div>
# <div class="hgroup">
# <h1><span class="person-name" lang="en">Ito Kentaro</span><span class="person-name" data-kana="いとう けんたろう" lang="ja">伊藤 健太郎</span></h1>
# <p class="subh"><span class="person-name">いとう けんたろう</span></p>
# </div>
# <div class="pgroup">
# <p><a class="sample-voice" data-style-variation="button" href="/talent/content/118.mp3" target="_blank">サンプルボイス</a></p>
# </div>
# <div class="pgroup">
# <p><a class="print-profile" href="/talent/ito-kentaro_print.html">プロフィールを印刷する</a></p>
# </div>
# <dl>
# <dt>誕生日</dt>
# <dd>1月3日</dd>
# <dt>出身地</dt>
# <dd>東京都</dd>
# <dt>方言</dt>
# <dd>-</dd>
# <dt>趣味・特技</dt>
# <dd>自転車・パーカッション</dd>
# <dt class="non-visual">関連ウェブサイト</dt>
# <dd>
# <ul>
# <li><a data-style-variation="icon website" href="http://itoken-ju.jugem.jp/" rel="external" target="_blank">Website</a></li>
# <li><a data-style-variation="icon twitter" href="https://twitter.com/itoken_k_show" rel="external" target="_blank">Twitter</a></li>
# </ul>
# </dd>
# </dl>
# <table>
# <tbody>
# <tr>
# <th scope="row">経歴</th>
# <td>平成7年：劇団21世紀FOX所属<br/>平成13年：東京俳優生活協同組合所属<br/>平成21年：アミュレート所属<br/>平成28年：マウスプロモーション所属</td>
# </tr>
# <tr>
# <th scope="row">主な出演作品</th>
# <td>
# <dl>
# <dt>アニメ</dt>
# <dd>「ゴールデンカムイ」（白石由竹）<br/>「弱虫ペダル」（田所迅）<br/>「BLEACH」（阿散井恋次）<br/>「NARUTO -ナルト-」（秋道チョウジ）<br/>「超者ライディーン」(鷲崎飛翔：ライディーンイーグル）<br/>「ONE PIECE」（フカボシ） <br/>「スーパードール★リカちゃん」（ドールイサム）<br/>「機動戦艦ナデシコ」（アオイ・ジュン）<br/>「とっとこハム太郎」シリーズ（タイショーくん）<br/>「GIANT KILLING」（黒田一樹）<br/>「金色のコルダ～primo passo～」（土浦梁太郎）<br/>「金色のコルダ Blue♪Sky」（八木沢雪広）<br/>「ジョジョの奇妙な冒険 スターダストクルセイダース」（ンドゥール） <br/>「ミュータント タートルズ」（ラファエロ）<br/>「カードファイト!!ヴァンガードシリーズ」（大文字ゴウキ）<br/>「純情ロマンチカ」シリーズ（上條弘樹）<br/>「鋼鉄三国志」（太史慈子義）<br/>「キングダム」第2シーズン（桓騎）<br/>「東京喰種トーキョーグール」（万丈数壱）</dd>
# <dt>吹き替え</dt>
# <dd>「ミュータント タートルズ」（レオナルド役）<br/>「アントマン」（デイヴ役）<br/>「ドラキュラZERO」（ドミニク・クーパー）<br/>「ある公爵夫人の生涯」（ドミニク・クーパー）<br/>「デビルズ・ダブル-ある影武者の物語-」（ドミニク・クーパー）<br/>「エラゴン 遺志を継ぐ者」（ギャレット・ヘドランド）<br/>「プライド 栄光への絆」（ギャレット・ヘドランド）<br/>「クラウドアトラス」（デヴィット・ジャーシー）<br/>「リベンジ・マッチ」（ダンテ・ストレート・Jr役）<br/>「タイタンズを忘れない」（ゲリー・バーティア役）<br/>「オールド･ルーキー」（ワック役）<br/>「ゴーストライダー」（ブラックハート役）<br/>「誘拐犯」（ジェファーズ役）<br/>「TRUE DETECTIVE/ロサンゼルス」（ポール・ウッドルー役）<br/>「THE TUDORS～背徳の王冠～」（チャールズ・ブランドン役）<br/>「ARROW」（トミー・マーリン役）<br/>「トゥルーブラッド」（ラファイエット・レイノルズ役）<br/>「ウェイワード・パインズ 出口のない街」（テレンス・ハワード）<br/>「偉天屠龍紀」（張無忌役）</dd>
# <dt>舞台</dt>
# <dd>劇団K-Show主宰 公演多数<br/>劇団21世紀FOX公演 出演多数</dd>
# <dt>ゲーム</dt>
# <dd>「テイルズ オブ ファンタジア」（チェスター・バークライト）<br/>「真・三國無双」シリーズ（楽進）</dd>
# <dt>その他</dt>
# <dd>「忍風戦隊ハリケンジャー」（穴掘り忍者モグドラゴの声）<br/>「超星艦隊セイザーⅩ」（火将軍ブレアードの声）<br/>「炎神戦隊ゴーオンジャー」（害水目蛮機獣マンホールバンキの声）</dd>
# </dl>
# </td>
# </tr>
# </tbody>
# </table>
# <div class="pgroup">
# <p><a data-style-variation="button" href="/talent/male/">男性タレント一覧へ</a></p>
# </div>
# <section class="fan-letter">
# <div class="hgroup">
# <h2>ファンレター送付先</h2>
# </div>
# <div class="pgroup">
# <p>ファンレターはタレント名を記載して、事務所宛にお送りください。</p>
# <p><small><span class="marker">※</span> 事務所宛ファンメールの受付は、基本的には行っておりませんのでご了承ください。</small></p>
# </div>
# <div class="pgroup">
# <p><a data-style-variation="button" href="/fan-letter/">送付先</a></p>
# </div>
# </section>
# </article>
# </main>
# <aside id="page-complementary" role="complementary">
# <ul class="parallel-list" data-style-variation="cols-3-3-3-3">
# <li><a href="/shop/original-anime/"><img alt="オリジナルアニメ マウスどうぶつえん" src="/content/images/common/banner_original-anime.png"/></a></li>
# <li><a href="/school/"><img alt="本気で声優めざすなら マウスプロモーション附属俳優養成所" src="/content/images/common/banner_school.png"/></a></li>
# <li><a href="http://www.amazon.co.jp/dp/4061385895" target="_blank"><img alt="大塚明夫の声優塾" src="/content/images/common/banner_seiyujuku.png"/></a></li>
# <li><a href="/shop/"><img alt="マウスショップ" src="/content/images/common/banner_shop.png"/></a></li>
# </ul>
# </aside>
# <footer id="page-footer" role="contentinfo">
# <aside>
# <ul>
# <li><a href="/about/#overview">会社概要</a></li>
# <li><a href="/#contact">お問い合わせ</a></li>
# <li><a href="/privacy/">プライバシーポリシー</a></li>
# <li><a href="/legal/">ご利用規約</a></li>
# </ul>
# <div class="pgroup">
# <address>© <a href="/">株式会社マウスプロモーション</a></address>
# </div>
# </aside>
# </footer>
# </body>
# </html>
# 1:  15%|█▍        | 5/34 [00:02<00:11,  2.49it/s]
# <!DOCTYPE html>
#
# <html class="agency" lang="ja" prefix="og: http://ogp.me/ns#" xml:lang="ja" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, user-scalable=yes" name="viewport"/>
# <title>井上 拓真 | 所属タレント | マウスプロモーション</title>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" name="description"/>
# <meta content="マウスプロモーション, マウスプロモーション附属俳優養成所, 俳優養成所, スタジオマウス, マウスショップ, 江崎, プロダクション, 声優, 養成所, MAUSU PROMOTION, STUDIO MAUSU" name="keywords"/>
# <link href="https://mausu.net/" rel="index" title="マウスプロモーション"/>
# <link href="/talent/inoue-takuma_print.html" media="print" rel="alternate" title="For Printing"/>
# <meta content="article" property="og:type"/>
# <meta content="井上 拓真 | 所属タレント | マウスプロモーション" property="og:title"/>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" property="og:description"/>
# <meta content="https://mausu.net/talent/content/d25668229e6944e6b892681895348d1a179c2a6e.jpg" property="og:image"/>
# <meta content="https://mausu.net/talent/inoue-takuma.html" property="og:url"/>
# <meta content="マウスプロモーション" property="og:site_name"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="mausu.net" name="twitter:domain"/>
# <meta content="井上 拓真 | 所属タレント | マウスプロモーション" name="twitter:title"/>
# <meta content="https://mausu.net/talent/inoue-takuma.html" name="twitter:url"/>
# <meta content="マウスプロモーションの所属タレントをサンプルボイス付きでご紹介します。印刷用の資料もございます。" name="twitter:description"/>
# <meta content="https://mausu.net/talent/content/d25668229e6944e6b892681895348d1a179c2a6e.jpg" name="twitter:image"/>
# <link href="/res/styles/mausu.css" rel="stylesheet"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-TF4G822');</script>
# <!-- End Google Tag Manager -->
# <script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 	ga('create', 'UA-81196363-1', 'auto');
# 	ga('send', 'pageview');
# 	</script>
# <script src="/res/scripts/mausu.js"></script>
# <link href="https://fonts.googleapis.com/css?family=M+PLUS+Rounded+1c:700&amp;display=swap" rel="stylesheet"/>
# <link href="/res/images/common/clipicon.png" rel="apple-touch-icon">
# <link href="/res/images/common/clipicon.png" rel="apple-touch-icon-precomposed"/>
# <link href="/res/images/common/favicon.ico" rel="shortcut icon"/>
# </link></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TF4G822" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header id="page-header" role="banner">
# <div class="hgroup" id="site-id">
# <h1 class="agency"><a href="/"><img alt="マウスプロモーション | Mausu Promotion" height="38" src="/res/images/common/logo-agency.svg"/></a></h1>
# </div>
# <nav id="global-nav" role="navigation">
# <input id="global-nav-switch" name="global-nav-switch" type="checkbox"/><label for="global-nav-switch">メニュー</label>
# <ul>
# <li class="agency"><a href="/"><span>マウスプロモーション</span></a>
# <ul>
# <li><a href="/about/"><span>マウスプロモーションについて</span></a></li>
# <li><a href="/talent/female/"><span>女性タレント</span></a></li>
# <li><a href="/talent/male/"><span>男性タレント</span></a></li>
# <li><a href="/topics/"><span>トピックス</span></a></li>
# <li><a href="/appearance/"><span>出演情報</span></a></li>
# </ul>
# <ul>
# <li><a href="/#contact"><span>お問い合わせ</span></a></li>
# <li><a href="/about/#access"><span>アクセス</span></a></li>
# </ul>
# </li>
# <li class="school"><a href="/school/"><span>マウスプロモーション</span><span>附属俳優養成所</span></a>
# <ul>
# <li><a href="/school/introduction.html"><span>授業内容</span></a></li>
# <li><a href="/school/teacher.html"><span>講師紹介</span></a></li>
# <li><a href="/school/graduate.html"><span>卒業生紹介</span></a></li>
# <li><a href="/school/scene.html"><span>授業風景</span></a></li>
# <li><a href="/school/fee.html"><span>授業料</span></a></li>
# <li><a href="/school/faq.html"><span>Q&amp;A</span></a></li>
# <li><a href="/school/applicants.html"><span>募集要項／入所の流れ</span></a></li>
# </ul>
# <ul>
# <li><a href="/school/contact.html"><span>お問い合わせ</span></a></li>
# </ul>
# </li>
# <li class="studio"><a href="/studio/"><span>スタジオマウス</span></a>
# <ul>
# <li><a href="/studio/about/"><span>スタジオマウスについて</span></a></li>
# <li><a href="/studio/studio1st.html"><span>Studio 1st.</span></a></li>
# <li><a href="/studio/studio2nd.html"><span>Studio 2nd.</span></a></li>
# <li><a href="/studio/works/"><span>作品リスト</span></a></li>
# </ul>
# <ul>
# <li><a href="/studio/#access"><span>アクセス</span></a></li>
# </ul>
# </li>
# <li class="shop"><a href="/shop/"><span>マウスショップ</span></a>
# <ul>
# <li><a href="/shop/about/"><span>マウスショップとは</span></a></li>
# <li><a href="/shop/event-info/"><span>イベント情報／お知らせ</span></a></li>
# <li><a href="/shop/original-anime/"><span>マウスどうぶつえん</span></a></li>
# <li><a href="/shop/original-goods"><span>オリジナルグッズ</span></a></li>
# </ul>
# <ul>
# <li><a href="/shop/original-anime/about/"><span>キャラ一覧</span></a></li>
# <li><a href="/shop/#access"><span>アクセス</span></a></li>
# </ul>
# </li>
# </ul>
# </nav>
# </header>
# ...
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 	ga('create', 'UA-81196363-1', 'auto');
# 	ga('send', 'pageview');
# 	</script>
# <script src="/res/scripts/mausu.js"></script>
# <link href="https://fonts.googleapis.com/css?family=M+PLUS+Rounded+1c:700&amp;display=swap" rel="stylesheet"/>
# <link href="/res/images/common/clipicon.png" rel="apple-touch-icon">
# <link href="/res/images/common/clipicon.png" rel="apple-touch-icon-precomposed"/>
# <link href="/res/images/common/favicon.ico" rel="shortcut icon"/>
# </link></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TF4G822" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header id="page-header" role="banner">
# <div class="hgroup" id="site-id">
# <h1 class="agency"><a href="/"><img alt="マウスプロモーション | Mausu Promotion" height="38" src="/res/images/common/logo-agency.svg"/></a></h1>
# </div>
# <nav id="global-nav" role="navigation">
# <input id="global-nav-switch" name="global-nav-switch" type="checkbox"/><label for="global-nav-switch">メニュー</label>
# <ul>
# <li class="agency"><a href="/"><span>マウスプロモーション</span></a>
# <ul>
# <li><a href="/about/"><span>マウスプロモーションについて</span></a></li>
# <li><a href="/talent/female/"><span>女性タレント</span></a></li>
# <li><a href="/talent/male/"><span>男性タレント</span></a></li>
# <li><a href="/topics/"><span>トピックス</span></a></li>
# <li><a href="/appearance/"><span>出演情報</span></a></li>
# </ul>
# <ul>
# <li><a href="/#contact"><span>お問い合わせ</span></a></li>
# <dt>CM・ナレーション</dt>
# <dd>「ニトリ　シブハチビジョン」<br/>「情報サイト　街ログ」<br/></dd>
# </dl>
# </td>
# </tr>
# </tbody>
# </table>
# <div class="pgroup">
# <p><a data-style-variation="button" href="/talent/female/">女性タレント一覧へ</a></p>
# </div>
# <section class="fan-letter">
# <div class="hgroup">
# <h2>ファンレター送付先</h2>
# </div>
# <div class="pgroup">
# <p>ファンレターはタレント名を記載して、事務所宛にお送りください。</p>
# <p><small><span class="marker">※</span> 事務所宛ファンメールの受付は、基本的には行っておりませんのでご了承ください。</small></p>
# </div>
# <div class="pgroup">
# <p><a data-style-variation="button" href="/fan-letter/">送付先</a></p>
# </div>
# </section>
# </article>
# </main>
# <aside id="page-complementary" role="complementary">
# <ul class="parallel-list" data-style-variation="cols-3-3-3-3">
# <li><a href="/shop/original-anime/"><img alt="オリジナルアニメ マウスどうぶつえん" src="/content/images/common/banner_original-anime.png"/></a></li>
# <li><a href="/school/"><img alt="本気で声優めざすなら マウスプロモーション附属俳優養成所" src="/content/images/common/banner_school.png"/></a></li>
# <li><a href="http://www.amazon.co.jp/dp/4061385895" target="_blank"><img alt="大塚明夫の声優塾" src="/content/images/common/banner_seiyujuku.png"/></a></li>
# <li><a href="/shop/"><img alt="マウスショップ" src="/content/images/common/banner_shop.png"/></a></li>
# </ul>
# </aside>
# <footer id="page-footer" role="contentinfo">
# <aside>
# <ul>
# <li><a href="/about/#overview">会社概要</a></li>
# <li><a href="/#contact">お問い合わせ</a></li>
# <li><a href="/privacy/">プライバシーポリシー</a></li>
# <li><a href="/legal/">ご利用規約</a></li>
# </ul>
# <div class="pgroup">
# <address>© <a href="/">株式会社マウスプロモーション</a></address>
# </div>
# </aside>
# </footer>
# </body>
# </html>
# [{'name': '安斉 一博',
#   'homepage': 'https://mausu.net/talent/anzai-kazuhiro.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/056.mp3',
#     'name': '056.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '石上 裕一',
#   'homepage': 'https://mausu.net/talent/ishigami-yuichi.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/057.mp3',
#     'name': '057.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '市来 光弘',
#   'homepage': 'https://mausu.net/talent/ichiki-mitsuhiro.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/116.mp3',
#     'name': '116.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '伊藤 健太郎',
#   'homepage': 'https://mausu.net/talent/ito-kentaro.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/118.mp3',
#     'name': '118.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '井上 拓真',
#   'homepage': 'https://mausu.net/talent/inoue-takuma.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/c0c8562460181513f4cffd68ec723ee82a6e3bab.mp3',
#     'name': 'c0c8562460181513f4cffd68ec723ee82a6e3bab.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '井上 雄貴',
#   'homepage': 'https://mausu.net/talent/inoue-yuki.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/inoue_Vs.mp3',
#     'name': 'inoue_Vs.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '伊丸岡 篤',
#   'homepage': 'https://mausu.net/talent/imaruoka-atsushi.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/055.mp3',
#     'name': '055.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '岩中 睦樹',
#   'homepage': 'https://mausu.net/talent/iwanaka-mutsuki.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/109.mp3',
#     'name': '109.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '臼木 健士朗',
#   'homepage': 'https://mausu.net/talent/usuki-kenshiro.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/022.mp3',
#     'name': '022.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '江川 大輔',
#   'homepage': 'https://mausu.net/talent/egawa-daisuke.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/048.mp3',
#     'name': '048.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '遠藤 大輔',
#   'homepage': 'https://mausu.net/talent/endou-daisuke.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/063.mp3',
#     'name': '063.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '大川 透',
#   'homepage': 'https://mausu.net/talent/okawa-toru.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/36e72e61429ca4250579cb316809df96b47aaacb.mp3',
#     'name': '36e72e61429ca4250579cb316809df96b47aaacb.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '大谷 祐貴',
#   'homepage': 'https://mausu.net/talent/post_4.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/e36e430b1526a806d53ab85668b32b677b7c342e.wav',
#     'name': 'e36e430b1526a806d53ab85668b32b677b7c342e.wav',
#     'description': 'サンプルボイス'}]},
#  {'name': '大塚 明夫',
#   'homepage': 'https://mausu.net/talent/otsuka-akio.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/044.mp3',
#     'name': '044.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '大泊 貴揮',
#   'homepage': 'https://mausu.net/talent/otomari-takaki.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/011.mp3',
#     'name': '011.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '大野 智敬',
#   'homepage': 'https://mausu.net/talent/ohno-tomohiro.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/67b460163cffb73fcbdbeef065717a5df809c214.mp3',
#     'name': '67b460163cffb73fcbdbeef065717a5df809c214.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '小形 満',
#   'homepage': 'https://mausu.net/talent/ogata-mitsuru.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/046.mp3',
#     'name': '046.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '奥田 寛章',
#   'homepage': 'https://mausu.net/talent/okuda-hiroaki.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/199651d93773edd22f3ae40b94c1d648ad023b52.mp3',
#     'name': '199651d93773edd22f3ae40b94c1d648ad023b52.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '奥村 翔',
#   'homepage': 'https://mausu.net/talent/okumura-show.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/027.mp3',
#     'name': '027.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '尾上 翔',
#   'homepage': 'https://mausu.net/talent/onoue-tsubasa.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/065.mp3',
#     'name': '065.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '小野塚 貴志',
#   'homepage': 'https://mausu.net/talent/onozuka-takashi.html',
#   'sex': 'Male',
#   'voices': [{'url': 'https://mausu.net/talent/content/047.mp3',
#     'name': '047.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '愛原 ありさ',
#   'homepage': 'https://mausu.net/talent/aihara-arisa.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/5486396b56c881ee9cc0a1dc5a7ed2ecbed6fe54.mp3',
#     'name': '5486396b56c881ee9cc0a1dc5a7ed2ecbed6fe54.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '足立 由夏',
#   'homepage': 'https://mausu.net/talent/adachi-yuka.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://mausu.net/talent/content/061.mp3',
#     'name': '061.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '尼子 絢那',
#   'homepage': 'https://mausu.net/talent/amako-junna.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/2ce0a1d97c1335c5a43fb6201a7e3109f9b1013d.mp3',
#     'name': '2ce0a1d97c1335c5a43fb6201a7e3109f9b1013d.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '飯沼 南実',
#   'homepage': 'https://mausu.net/talent/iinuma-minami.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/54007ffba885084870a9e28e645ef70c64544102.mp3',
#     'name': '54007ffba885084870a9e28e645ef70c64544102.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '五十嵐 裕美',
#   'homepage': 'https://mausu.net/talent/igarashi-hiromi.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://mausu.net/talent/content/093.mp3',
#     'name': '093.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '遠藤 勝代',
#   'homepage': 'https://mausu.net/talent/endo-katsuyo.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://mausu.net/talent/content/001.mp3',
#     'name': '001.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '大田 菜乃子',
#   'homepage': 'https://mausu.net/talent/ota-nanoko.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/3143ee693c0a9cb3783e195f3054d34ae3f85767.mp3',
#     'name': '3143ee693c0a9cb3783e195f3054d34ae3f85767.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '大谷 育江',
#   'homepage': 'https://mausu.net/talent/otani-ikue.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://mausu.net/talent/content/005.mp3',
#     'name': '005.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '大野 柚布子',
#   'homepage': 'https://mausu.net/talent/ono-yuko.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/391b874a51f577b4756b4f153e073d9447dc62b5.mp3',
#     'name': '391b874a51f577b4756b4f153e073d9447dc62b5.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '大橋 歩夕',
#   'homepage': 'https://mausu.net/talent/ohashi-ayuru.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/b9b4779bace0d16c158d3fc790f0681db16088f3.mp3',
#     'name': 'b9b4779bace0d16c158d3fc790f0681db16088f3.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '岡村 明美',
#   'homepage': 'https://mausu.net/talent/okamura-akemi.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://mausu.net/talent/content/002.mp3',
#     'name': '002.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '小澤 みなみ',
#   'homepage': 'https://mausu.net/talent/ozawa-minami.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/a908a5628930fecfc12824d19e6fad6f44f8d5f0.mp3',
#     'name': 'a908a5628930fecfc12824d19e6fad6f44f8d5f0.mp3',
#     'description': 'サンプルボイス'}]},
#  {'name': '織部 ゆかり',
#   'homepage': 'https://mausu.net/talent/oribe-yukari.html',
#   'sex': 'Female',
#   'voices': [{'url': 'https://mausu.nethttps://mausu.net/talent/content/e21ca76458648dd1a2aa7d487c5983d85cb91630.mp3',
#     'name': 'e21ca76458648dd1a2aa7d487c5983d85cb91630.mp3',
#     'description': 'サンプルボイス'}]}]

# %%
import json
with open("../jsons/mausu.json", "w",encoding='utf-8') as f:
    json.dump(actors, f, ensure_ascii=False, indent=2)

all_voices = []
for actor in actors:
    for voice in actor["voices"]:
        all_voices.append(voice)
len(all_voices)
# Out:
# 34
